# %% [markdown]
# # Problem 1: Diffusion

# %%
# !pip install smalldiffusion
# Out:
# Collecting smalldiffusion
#   Downloading smalldiffusion-0.3-py3-none-any.whl.metadata (10 kB)
# Collecting accelerate (from smalldiffusion)
#   Downloading accelerate-0.29.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from smalldiffusion) (1.26.0)
# Requirement already satisfied: torchvision in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from smalldiffusion) (0.16.2+cu118)
# Requirement already satisfied: torch in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from smalldiffusion) (2.1.2+cu118)
# Requirement already satisfied: tqdm in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from smalldiffusion) (4.66.1)
# Collecting einops (from smalldiffusion)
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from accelerate->smalldiffusion) (23.1)
# Requirement already satisfied: psutil in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from accelerate->smalldiffusion) (5.9.5)
# Requirement already satisfied: pyyaml in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from accelerate->smalldiffusion) (6.0.1)
# Collecting huggingface-hub (from accelerate->smalldiffusion)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Collecting safetensors>=0.3.1 (from accelerate->smalldiffusion)
#   Downloading safetensors-0.4.3-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: filelock in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torch->smalldiffusion) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torch->smalldiffusion) (4.9.0)
# Requirement already satisfied: sympy in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torch->smalldiffusion) (1.12)
# Requirement already satisfied: networkx in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torch->smalldiffusion) (3.2)
# Requirement already satisfied: jinja2 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torch->smalldiffusion) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torch->smalldiffusion) (2023.4.0)
# Requirement already satisfied: requests in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torchvision->smalldiffusion) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from torchvision->smalldiffusion) (10.0.1)
# Requirement already satisfied: colorama in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from tqdm->smalldiffusion) (0.4.6)
# Collecting fsspec (from torch->smalldiffusion)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch->smalldiffusion) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision->smalldiffusion) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision->smalldiffusion) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision->smalldiffusion) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision->smalldiffusion) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\fenst\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch->smalldiffusion) (1.3.0)
# Downloading smalldiffusion-0.3-py3-none-any.whl (12 kB)
# Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#    ---------------------------------------- 0.0/297.6 kB ? eta -:--:--
#    --------------------------------------  297.0/297.6 kB 19.1 MB/s eta 0:00:01
#    ---------------------------------------- 297.6/297.6 kB 6.1 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB 2.3 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp311-none-win_amd64.whl (287 kB)
#    ---------------------------------------- 0.0/287.3 kB ? eta -:--:--
#    --------------------------------------- 287.3/287.3 kB 17.3 MB/s eta 0:00:00
# Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#    ---------------------------------------- 0.0/388.9 kB ? eta -:--:--
#    --------------------------------------- 388.9/388.9 kB 12.2 MB/s eta 0:00:00
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ---------------------------------------- 0.0/172.0 kB ? eta -:--:--
#    --------------------------------------- 172.0/172.0 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: safetensors, fsspec, einops, huggingface-hub, accelerate, smalldiffusion
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
# Successfully installed accelerate-0.29.3 einops-0.7.0 fsspec-2024.3.1 huggingface-hub-0.22.2 safetensors-0.4.3 smalldiffusion-0.3

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from smalldiffusion import ScheduleLogLinear, TimeInputMLP, training_loop, samples, Swissroll

# %%
# Helper functions
def plot_batch(batch):
  plt.scatter(batch[:,0], batch[:,1], marker='.')
  plt.axis([-1.5, 1.5, -1.5, 1.5])
  plt.gca().set_aspect('equal')

def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %% [markdown]
# Load and plot the Swisroll data

# %%
dataset = Swissroll(np.pi/2, 5*np.pi, 100)
loader = DataLoader(dataset, batch_size=2130)
plot_batch(next(iter(loader)))

# %% [markdown]
# Generate and plot the log-linear sigma schedule

# %%
#create schedule, a list starting at 0.01 and ending at 10 consisting of 200 steps
schedule = my_list = ScheduleLogLinear(200, 0.01, 10)
plt.plot(schedule)
plt.xlabel('$t$')
plt.ylabel('$\sigma_t$')
plt.yscale('log')

# %% [markdown]
# Define a simple diffusion model using a MultiLayer Perceptron

# %%
model = TimeInputMLP(hidden_dims=(16,128,128,128,128,16))
print(model)
# Out:
# TimeInputMLP(
#   (net): Sequential(
#     (0): Linear(in_features=4, out_features=16, bias=True)
#     (1): GELU(approximate='none')
#     (2): Linear(in_features=16, out_features=128, bias=True)
#     (3): GELU(approximate='none')
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): GELU(approximate='none')
#     (6): Linear(in_features=128, out_features=128, bias=True)
#     (7): GELU(approximate='none')
#     (8): Linear(in_features=128, out_features=128, bias=True)
#     (9): GELU(approximate='none')
#     (10): Linear(in_features=128, out_features=16, bias=True)
#     (11): GELU(approximate='none')
#     (12): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# Train the diffusion model

# %%
# Referencing documentation for training_loop, implement the trainer and plot a moving average of the losses. Use 10000 epochs and a learning rate of 10−3. Include your code snippet and plot below.
trainer = training_loop(loader, model, schedule, epochs=10000, lr=1e-3)

losses = [ns.loss.item() for ns in trainer]
plt.plot(moving_average(losses, 100))
plt.show()
# Out:
# 100%|██████████| 10000/10000 [00:55<00:00, 180.64it/s]

# %% [markdown]
# For DDIM sampling keep parameters gam=1 and mu=0

# %%
steps = 10
*_, sampled_x = samples(model, schedule.sample_sigmas(steps), batchsize=1500, gam=1, mu=0)
plot_batch(sampled_x)

# %%
steps = 100
*_, sampled_x = samples(model, schedule.sample_sigmas(steps), batchsize=1500, gam=1, mu=0)
plot_batch(sampled_x)

# %%
steps = 300
*_, sampled_x = samples(model, schedule.sample_sigmas(steps), batchsize=1500, gam=1, mu=0)
plot_batch(sampled_x)

# %%
steps = 1000
*_, sampled_x = samples(model, schedule.sample_sigmas(steps), batchsize=1500, gam=1, mu=0)
plot_batch(sampled_x)

# %%
steps = 400
*_, sampled_x = samples(model, schedule.sample_sigmas(steps), batchsize=1500, gam=1, mu=0)
plot_batch(sampled_x)

# %%
steps = 399
*_, sampled_x = samples(model, schedule.sample_sigmas(steps), batchsize=1500, gam=1, mu=0)
plot_batch(sampled_x)

# %% [markdown]
# # Problem 2: Interpretability

# %%
# !pip install lime

# %% [markdown]
# # Using Lime with Pytorch

# %% [markdown]
# In this tutorial we will show how to use Lime framework with Pytorch. Specifically, we will use Lime to explain the prediction generated by one of the pretrained ImageNet models.
#
# Let's start with importing our dependencies. This code is tested with Pytorch 1.0 but should work with older versions as well.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import torch.nn as nn
import numpy as np
import os, json

import torch
from torchvision import models, transforms
from torch.autograd import Variable
import torch.nn.functional as F

# %% [markdown]
# Load our test image and see how it looks.

# %%
def get_image(path):
    with open(os.path.abspath(path), 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB')

img = get_image('./data/dogs.png')
plt.imshow(img)

# %% [markdown]
# We need to convert this image to Pytorch tensor and also apply whitening as used by our pretrained model.

# %%
# resize and take the center part of image to what our model expects
def get_input_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    return transf

def get_input_tensors(img):
    transf = get_input_transform()
    # unsqeeze converts single image to batch of 1
    return transf(img).unsqueeze(0)

# %% [markdown]
# Load the pretrained model for Resnet50 available in Pytorch.

# %%
model = models.inception_v3(pretrained=True)

# %% [markdown]
# Load label texts for ImageNet predictions so we know what model is predicting

# %%
idx2label, cls2label, cls2idx = [], {}, {}
with open(os.path.abspath('./data/imagenet_class_index.json'), 'r') as read_file:
    class_idx = json.load(read_file)
    idx2label = [class_idx[str(k)][1] for k in range(len(class_idx))]
    cls2label = {class_idx[str(k)][0]: class_idx[str(k)][1] for k in range(len(class_idx))}
    cls2idx = {class_idx[str(k)][0]: k for k in range(len(class_idx))}

# %% [markdown]
# Get the predicition for our image.

# %%
img_t = get_input_tensors(img)
model.eval()
logits = model(img_t)

# %% [markdown]
# Predicitions we got are logits. Let's pass that through softmax to get probabilities and class labels for top 5 predictions.

# %%
probs = F.softmax(logits, dim=1)
probs5 = probs.topk(5)
tuple((p,c, idx2label[c]) for p, c in zip(probs5[0][0].detach().numpy(), probs5[1][0].detach().numpy()))

# %% [markdown]
# We are getting ready to use Lime. Lime produces the array of images from original input image by pertubation algorithm. So we need to provide two things: (1) original image as numpy array (2) classification function that would take array of purturbed images as input and produce the probabilities for each class for each image as output.
#
# For Pytorch, first we need to define two separate transforms: (1) to take PIL image, resize and crop it (2) take resized, cropped image and apply whitening.

# %%
def get_pil_transform():
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224)
    ])

    return transf

def get_preprocess_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])
    transf = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])

    return transf

pill_transf = get_pil_transform()
preprocess_transform = get_preprocess_transform()

# %% [markdown]
# Now we are ready to define classification function that Lime needs. The input to this function is numpy array of images where each image is ndarray of shape (channel, height, width). The output is numpy aaray of shape (image index, classes) where each value in array should be probability for that image, class combination.

# %%
def batch_predict(images):
    model.eval()
    batch = torch.stack(tuple(preprocess_transform(i) for i in images), dim=0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    batch = batch.to(device)

    logits = model(batch)
    probs = F.softmax(logits, dim=1)
    return probs.detach().cpu().numpy()

# %% [markdown]
# Let's test our function for the sample image.

# %%
test_pred = batch_predict([pill_transf(img)])
test_pred.squeeze().argmax()
# Out:
# 239

# %% [markdown]
# Import lime and create explanation for this prediciton.

# %%
from lime import lime_image

# %%
explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)),
                                         batch_predict,
                                         top_labels=5,
                                         hide_color=0,
                                         num_samples=1000)

# %% [markdown]
# Let's use mask on image and see the areas that are encouraging the top prediction.

# %%
from skimage.segmentation import mark_boundaries

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
img_boundry1 = mark_boundaries(temp/255.0, mask)
plt.imshow(img_boundry1)

# %% [markdown]
# # Experimentation

# %% [markdown]
# Change the parameters and see how it affects the output for parts 3.2-3.4. For 3.4 (grad), you can change parameters that are not explicitly listed!

# %%
explainer = lime_image.LimeImageExplainer(kernel_width=0.25)
explanation = explainer.explain_instance(np.array(pill_transf(img)),
                                         batch_predict,
                                         top_labels=5,
                                         hide_color=0,
                                         distance_metric='cosine',
                                         num_samples=1000)

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
img_boundry2 = mark_boundaries(temp/255.0, mask)
plt.imshow(img_boundry2)
