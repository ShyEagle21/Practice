# %%
import Dual_sim_SC as dss
import pandas as pd
import Dual_sim_SC_variability as dssv
import Dual_sim_SC_Change_1 as dssc1
import Dual_sim_SC_Change_1_variability as dssc1v

# %%
feature_values = {
    'yesterday_total_packages': 8500,
    'RAFT_known_shipped_pkg_count': 2500,
    'RAFT_predicted_carryover_pkg_count': 28,
    'RAFT_predicted_total_handoff_pkg_count': 3500,
    'Day of Week_Sunday': 0,
    'Day of Week_Monday': 1,
    'Day of Week_Tuesday': 0,
    'Day of Week_Wednesday': 0,
    'Day of Week_Thursday': 0,
    'Day of Week_Friday': 0,
    'Day of Week_Saturday': 0,
    'Promotion': 0,
    'TMAX': 36.2,
    'TMIN': 31.8,
    'AWND': 9.87,
    'PRCP': 0.912,
    'SNOW': 6.14
        }
variance = 0.1
### Labor Allocations ###
night_total_tm = 26

night_tm_pit_unload = 2
night_tm_pit_induct = 8 # must be fewer than 8 or whatever the number of induct spaces is
night_tm_nonpit_split = 1  # must be 1
night_tm_nonpit_NC = 4
night_tm_nonpit_buffer = 11

#NIGHTS TLMD SORT ALLOCATION
night_tm_TLMD_induct = 4  #must be 6 or fewer
night_tm_TLMD_induct_stage = 1
night_tm_TLMD_picker = 4  #Must be 4
night_tm_TLMD_sort = 17

#NIGHTS TLMD STAGE ALLOCATION
night_tm_TLMD_stage = 26
day_total_tm = 20

#DAYS INBOUND INDUCT ALLOCATION
day_tm_pit_unload = 2 
day_tm_pit_induct = 5 # must be fewer than 8 or whatever the number of induct spaces is
day_tm_nonpit_split = 1   # must be 1
day_tm_nonpit_NC = 3
day_tm_nonpit_buffer = 9

#NIGHTS TLMD SORT ALLOCATION
day_tm_TLMD_induct = 3 # must be 6 or fewer
day_tm_TLMD_induct_stage = 1
day_tm_TLMD_picker = 4  #Must be 4
day_tm_TLMD_sort = 12


#DAYSS TLMD STAGE ALLOCATION
day_tm_TLMD_stage = 20



USPS_Fluid_Status = False
UPSN_Fluid_Status = False
FDEG_Fluid_Status = False
FDE_Fluid_Status = False

# %%
# Run for trial results of current process with and without process variability
results_tracker = {}
results_tracker_var = {}
linehaul_tracker = {}
TFC_tracker = {}

for i in range(0, 100):
    print(f"Trial: {i}")
    results, results_var, df_package_distribution, TFC_arrival_minutes  = dss.Simulation_Machine(feature_values,
                        night_total_tm,
                        day_total_tm,
                        night_tm_pit_unload, 
                            night_tm_pit_induct, 
                            night_tm_nonpit_split, 
                            night_tm_nonpit_NC, 
                            night_tm_nonpit_buffer,
                            night_tm_TLMD_induct,
                            night_tm_TLMD_induct_stage,
                            night_tm_TLMD_picker,
                            night_tm_TLMD_sort, 
                            night_tm_TLMD_stage,
                            day_tm_pit_unload,
                            day_tm_pit_induct,
                            day_tm_nonpit_split,
                            day_tm_nonpit_NC,
                            day_tm_nonpit_buffer,
                            day_tm_TLMD_induct,
                            day_tm_TLMD_induct_stage,
                            day_tm_TLMD_picker,
                            day_tm_TLMD_sort,
                            day_tm_TLMD_stage,
                            USPS_Fluid_Status,
                            UPSN_Fluid_Status,
                            FDEG_Fluid_Status,
                            FDE_Fluid_Status,
                        )
    results_tracker[i] = results
    results_tracker_var[i] = results_var
    linehaul_tracker[i] = df_package_distribution
    TFC_tracker[i] = TFC_arrival_minutes

df = pd.DataFrame.from_dict(results_tracker, orient='index')
df_var = pd.DataFrame.from_dict(results_tracker_var, orient='index')

# Display the DataFrame
df.to_csv('results.csv')
df_var.to_csv('results_var.csv')
# Out:
# Trial: 0
# Variability
# No Variability
# Trial: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       7 for i in range(0, 100):
#       8     print(f"Trial: {i}")
# ----> 9     results, results_var, df_package_distribution, TFC_arrival_minutes  = dss.Simulation_Machine(feature_values,
#      10                         night_total_tm,
#      11                         day_total_tm,
#      12                         night_tm_pit_unload,
#      13                             night_tm_pit_induct,
#      14                             night_tm_nonpit_split,
#      15                             night_tm_nonpit_NC,
#      16                             night_tm_nonpit_buffer,
#      17                             night_tm_TLMD_induct,
#      18                             night_tm_TLMD_induct_stage,
#      19                             night_tm_TLMD_picker,
#      20                             night_tm_TLMD_sort,
#      21                             night_tm_TLMD_stage,
#      22                             day_tm_pit_unload,
#      23                             day_tm_pit_induct,
#      24                             day_tm_nonpit_split,
#      25                             day_tm_nonpit_NC,
#      26                             day_tm_nonpit_buffer,
#      27                             day_tm_TLMD_induct,
#      28                             day_tm_TLMD_induct_stage,
#      29                             day_tm_TLMD_picker,
#      30                             day_tm_TLMD_sort,
#      31                             day_tm_TLMD_stage,
#      32                             USPS_Fluid_Status,
#      33                             UPSN_Fluid_Status,
#      34                             FDEG_Fluid_Status,
#      35                             FDE_Fluid_Status,
#      36                         )
#      37     results_tracker[i] = results
#      38     results_tracker_var[i] = results_var
#
# File c:\Users\fenst\Documents\Python\Practice\Dual_sim_SC.py:1399, in Simulation_Machine(feature_values, night_total_tm, day_total_tm, night_tm_pit_unload, night_tm_pit_induct, night_tm_nonpit_split, night_tm_nonpit_NC, night_tm_nonpit_buffer, night_tm_TLMD_induct, night_tm_TLMD_induct_stage, night_tm_TLMD_picker, night_tm_TLMD_sort, night_tm_TLMD_stage, day_tm_pit_unload, day_tm_pit_induct, day_tm_nonpit_split, day_tm_nonpit_NC, day_tm_nonpit_buffer, day_tm_TLMD_induct, day_tm_TLMD_induct_stage, day_tm_TLMD_picker, day_tm_TLMD_sort, day_tm_TLMD_stage, USPS_Fluid_Status, UPSN_Fluid_Status, FDEG_Fluid_Status, FDE_Fluid_Status)
#    1369 def Simulation_Machine(feature_values,
#    1370                        night_total_tm,
#    1371                        day_total_tm,
#    (...)
#    1395                         FDE_Fluid_Status,
#    1396                         ):
# -> 1399     df_pallets, df_package_distribution, TFC_arrival_minutes = sg.simulation_generator(False, feature_values)
#    1401     pallet_info = df_pallets.groupby('Pallet').agg(
#    1402         num_packages=('package_tracking_number', 'count'),
#    1403         earliest_arrival=('pkg_received_utc_ts', 'min'),
#    1404         packages=('package_tracking_number', lambda x: list(zip(x, df_pallets.loc[x.index, 'scac']))),
#    1405         linehaul=('Linehaul', 'first')
#    1406     ).reset_index()
#    1408     if night_tm_pit_unload + night_tm_pit_induct + night_tm_nonpit_split + night_tm_nonpit_NC + night_tm_nonpit_buffer > night_total_tm:
#
# File c:\Users\fenst\Documents\Python\Practice\sim_generator.py:19, in simulation_generator(Train, feature_values, model_file_path, csv_train_file_path)
#      16 predicted_volume = vp.predict_volume(model, feature_values)
#      17 #print(f'Predicted Total Volume: {predicted_volume}')
# ---> 19 df_package_distribution, TFC_vol, TFC_arrival_minutes = dg.generate_demand('linehaul_all_predict - Copy.csv', 3858, predicted_volume, '2024-09-01')
#      21 csv_file = 'carrier_breakdown.csv'
#      22 distributions = pd.read_csv(csv_file)
#
# File c:\Users\fenst\Documents\Python\Practice\demand_generator.py:87, in generate_demand(csv_file, sortation_center_id, predicted_volume, prediction_date)
#      84 if arrival_time.time() < datetime.strptime('15:00:00', '%H:%M:%S').time():
#      85     arrival_time += pd.Timedelta(days=1)
# ---> 87 shift_time = pd.to_datetime(f"{row['inbound_date']} {start_time}")
#      88 truck_df.at[idx, 'shift_time'] = shift_time
#      89 truck_df.at[idx, 'arrival_time'] = arrival_time
#
# File c:\Users\fenst\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1101, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1099         result = convert_listlike(argc, format)
#    1100 else:
# -> 1101     result = convert_listlike(np.array([arg]), format)[0]
#    1102     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1103         result = bool(result)  # TODO: avoid this kludge.
#
# File c:\Users\fenst\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:429, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     426 arg = ensure_object(arg)
#     428 if format is None:
# --> 429     format = _guess_datetime_format_for_array(arg, dayfirst=dayfirst)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
#
# File c:\Users\fenst\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:131, in _guess_datetime_format_for_array(arr, dayfirst)
#     128 if (first_non_null := tslib.first_non_null(arr)) != -1:
#     129     if type(first_non_nan_element := arr[first_non_null]) is str:  # noqa: E721
#     130         # GH#32264 np.str_ object
# --> 131         guessed_format = guess_datetime_format(
#     132             first_non_nan_element, dayfirst=dayfirst
#     133         )
#     134         if guessed_format is not None:
#     135             return guessed_format
#
# File parsing.pyx:1013, in pandas._libs.tslibs.parsing.guess_datetime_format()
#
# File parsing.pyx:1072, in pandas._libs.tslibs.parsing._fill_token()
#
# File c:\Users\fenst\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:176, in search(pattern, string, flags)
#     173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
# --> 176     return _compile(pattern, flags).search(string)
#
# File c:\Users\fenst\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:272, in _compile(pattern, flags)
#     269 _cache = {}  # ordered!
#     271 _MAXCACHE = 512
# --> 272 def _compile(pattern, flags):
#     273     # internal: compile pattern
#     274     if isinstance(flags, RegexFlag):
#     275         flags = flags.value
#
# KeyboardInterrupt:

# %%
#Run this block to analyze the effects of process variability on the established set up of conditions based on current process set up.

results_tracker = {}
results_tracker_var_05 = {}
results_tracker_var_1 = {}
results_tracker_var_15 = {}
results_tracker_var_2 = {}
results_tracker_var_25 = {}
results_tracker_var_3 = {}
results_tracker_var_35 = {}
results_tracker_var_4 = {}
linehaul_tracker = {}
TFC_tracker = {}

for i in range(0, 50):
    print(f"Trial: {i}")
    results, results_var_05,results_var_1,results_var_15,results_var_2,results_var_25,results_var_3,results_var_35,results_var_4, df_package_distribution, TFC_arrival_minutes  = dssv.Simulation_Machine(feature_values,
                        night_total_tm,
                        day_total_tm,
                        night_tm_pit_unload, 
                            night_tm_pit_induct, 
                            night_tm_nonpit_split, 
                            night_tm_nonpit_NC, 
                            night_tm_nonpit_buffer,
                            night_tm_TLMD_induct,
                            night_tm_TLMD_induct_stage,
                            night_tm_TLMD_picker,
                            night_tm_TLMD_sort, 
                            night_tm_TLMD_stage,
                            day_tm_pit_unload,
                            day_tm_pit_induct,
                            day_tm_nonpit_split,
                            day_tm_nonpit_NC,
                            day_tm_nonpit_buffer,
                            day_tm_TLMD_induct,
                            day_tm_TLMD_induct_stage,
                            day_tm_TLMD_picker,
                            day_tm_TLMD_sort,
                            day_tm_TLMD_stage,
                            USPS_Fluid_Status,
                            UPSN_Fluid_Status,
                            FDEG_Fluid_Status,
                            FDE_Fluid_Status)
    
    results_tracker[i] = results
    results_tracker_var_05[i] = results_var_05
    results_tracker_var_1[i] = results_var_1
    results_tracker_var_15[i] = results_var_15
    results_tracker_var_2[i] = results_var_2
    results_tracker_var_25[i] = results_var_25
    results_tracker_var_3[i] = results_var_3
    results_tracker_var_35[i] = results_var_35
    results_tracker_var_4[i] = results_var_4

    linehaul_tracker[i] = df_package_distribution
    TFC_tracker[i] = TFC_arrival_minutes

df = pd.DataFrame.from_dict(results_tracker, orient='index')
df_var_05 = pd.DataFrame.from_dict(results_tracker_var_05, orient='index')
df_var_1 = pd.DataFrame.from_dict(results_tracker_var_1, orient='index')
df_var_15 = pd.DataFrame.from_dict(results_tracker_var_15, orient='index')
df_var_2 = pd.DataFrame.from_dict(results_tracker_var_2, orient='index')
df_var_25 = pd.DataFrame.from_dict(results_tracker_var_25, orient='index')
df_var_3 = pd.DataFrame.from_dict(results_tracker_var_3, orient='index')
df_var_35 = pd.DataFrame.from_dict(results_tracker_var_35, orient='index')
df_var_4 = pd.DataFrame.from_dict(results_tracker_var_4, orient='index')

# Display the DataFrame
df.to_csv('results.csv')
df_var_05.to_csv('results_var_05.csv')
df_var_1.to_csv('results_var_1.csv')
df_var_15.to_csv('results_var_15.csv')
df_var_2.to_csv('results_var_2.csv')
df_var_25.to_csv('results_var_25.csv')
df_var_3.to_csv('results_var_3.csv')
df_var_35.to_csv('results_var_35.csv')
df_var_4.to_csv('results_var_4.csv')

# %%
# Run for trial results of Linehaul C change with and without process variability
results_tracker = {}
results_tracker_var = {}
linehaul_tracker = {}
TFC_tracker = {}

for i in range(0, 50):
    print(f"Trial: {i}")
    results, results_var, df_package_distribution, TFC_arrival_minutes  = dssc1.Simulation_Machine(feature_values,
                        night_total_tm,
                        day_total_tm,
                        night_tm_pit_unload, 
                            night_tm_pit_induct, 
                            night_tm_nonpit_split, 
                            night_tm_nonpit_NC, 
                            night_tm_nonpit_buffer,
                            night_tm_TLMD_induct,
                            night_tm_TLMD_induct_stage,
                            night_tm_TLMD_picker,
                            night_tm_TLMD_sort, 
                            night_tm_TLMD_stage,
                            day_tm_pit_unload,
                            day_tm_pit_induct,
                            day_tm_nonpit_split,
                            day_tm_nonpit_NC,
                            day_tm_nonpit_buffer,
                            day_tm_TLMD_induct,
                            day_tm_TLMD_induct_stage,
                            day_tm_TLMD_picker,
                            day_tm_TLMD_sort,
                            day_tm_TLMD_stage,
                            USPS_Fluid_Status,
                            UPSN_Fluid_Status,
                            FDEG_Fluid_Status,
                            FDE_Fluid_Status)
    results_tracker[i] = results
    results_tracker_var[i] = results_var
   


    linehaul_tracker[i] = df_package_distribution
    TFC_tracker[i] = TFC_arrival_minutes

df = pd.DataFrame.from_dict(results_tracker, orient='index')

df_var = pd.DataFrame.from_dict(results_tracker_var, orient='index')



# Display the DataFrame
df.to_csv('results.csv')
df_var.to_csv('results_var.csv')

# %%
#Run this block to analyze the effects of process variability on the established set up of conditions based on Line Haul C discrimination.

results_tracker = {}
results_tracker_var_05 = {}
results_tracker_var_1 = {}
results_tracker_var_15 = {}
results_tracker_var_2 = {}
results_tracker_var_25 = {}
results_tracker_var_3 = {}
results_tracker_var_35 = {}
results_tracker_var_4 = {}
linehaul_tracker = {}
TFC_tracker = {}

for i in range(0, 50):
    print(f"Trial: {i}")
    results, results_var_05,results_var_1,results_var_15,results_var_2,results_var_25,results_var_3,results_var_35,results_var_4, df_package_distribution, TFC_arrival_minutes  = dssc1v.Simulation_Machine(feature_values,
                        night_total_tm,
                        day_total_tm,
                        night_tm_pit_unload, 
                            night_tm_pit_induct, 
                            night_tm_nonpit_split, 
                            night_tm_nonpit_NC, 
                            night_tm_nonpit_buffer,
                            night_tm_TLMD_induct,
                            night_tm_TLMD_induct_stage,
                            night_tm_TLMD_picker,
                            night_tm_TLMD_sort, 
                            night_tm_TLMD_stage,
                            day_tm_pit_unload,
                            day_tm_pit_induct,
                            day_tm_nonpit_split,
                            day_tm_nonpit_NC,
                            day_tm_nonpit_buffer,
                            day_tm_TLMD_induct,
                            day_tm_TLMD_induct_stage,
                            day_tm_TLMD_picker,
                            day_tm_TLMD_sort,
                            day_tm_TLMD_stage,
                            USPS_Fluid_Status,
                            UPSN_Fluid_Status,
                            FDEG_Fluid_Status,
                            FDE_Fluid_Status)
    
    results_tracker[i] = results
    results_tracker_var_05[i] = results_var_05
    results_tracker_var_1[i] = results_var_1
    results_tracker_var_15[i] = results_var_15
    results_tracker_var_2[i] = results_var_2
    results_tracker_var_25[i] = results_var_25
    results_tracker_var_3[i] = results_var_3
    results_tracker_var_35[i] = results_var_35
    results_tracker_var_4[i] = results_var_4

    linehaul_tracker[i] = df_package_distribution
    TFC_tracker[i] = TFC_arrival_minutes

df = pd.DataFrame.from_dict(results_tracker, orient='index')
df_var_05 = pd.DataFrame.from_dict(results_tracker_var_05, orient='index')
df_var_1 = pd.DataFrame.from_dict(results_tracker_var_1, orient='index')
df_var_15 = pd.DataFrame.from_dict(results_tracker_var_15, orient='index')
df_var_2 = pd.DataFrame.from_dict(results_tracker_var_2, orient='index')
df_var_25 = pd.DataFrame.from_dict(results_tracker_var_25, orient='index')
df_var_3 = pd.DataFrame.from_dict(results_tracker_var_3, orient='index')
df_var_35 = pd.DataFrame.from_dict(results_tracker_var_35, orient='index')
df_var_4 = pd.DataFrame.from_dict(results_tracker_var_4, orient='index')

# Display the DataFrame
df.to_csv('results.csv')
df_var_05.to_csv('results_var_05.csv')
df_var_1.to_csv('results_var_1.csv')
df_var_15.to_csv('results_var_15.csv')
df_var_2.to_csv('results_var_2.csv')
df_var_25.to_csv('results_var_25.csv')
df_var_3.to_csv('results_var_3.csv')
df_var_35.to_csv('results_var_35.csv')
df_var_4.to_csv('results_var_4.csv')
