# %% [markdown]
# # Define Classes, Libraries, and Global Variables that will be used across all simulations

# %%
import os
import random
from datetime import datetime, timedelta
import math

import matplotlib.pyplot as plt
import pandas as pd
import simpy

class G:
    # Constants (adjust as needed)
    Process_Variance = 0.1
    UNLOADING_RATE = 60/15  # minutes per pallet
    UNLOADING_VARIANCE = Process_Variance  # 10% variance
    INDUCT_STAGE_RATE = 60/22  # minutes per pallet
    INDUCT_STAGE_VARIANCE = Process_Variance  # 10% variance
    INDUCTION_RATE = 60/800  # minutes per package
    INDUCTION_VARIANCE = Process_Variance  # 10% variance
    SPLITTER_RATE = 1/60  # minutes per package
    SPLITTER_VARIANCE = Process_Variance  # 10% variance
    TLMD_BUFFER_SORT_RATE = 60/148  # minutes per package
    TLMD_BUFFER_SORT_VARIANCE = Process_Variance  # 10% variance
    TLMD_PARTITION_STAGE_RATE = 1  # minutes per pallet
    TLMD_PARTITION_STAGE_VARIANCE = Process_Variance  # 10% variance
    TLMD_INDUCT_STAGE_RATE = 60/15  # minutes per pallet
    TLMD_INDUCT_STAGE_VARIANCE = Process_Variance  # 10% variance
    TLMD_INDUCTION_RATE = 60/300  # minutes per package
    TLMD_INDUCTION_VARIANCE = Process_Variance  # 10% variance
    TLMD_FINAL_SORT_RATE = 60/84  # minutes per package
    TLMD_FINAL_SORT_VARIANCE = Process_Variance  # 10% variance
    TLMD_CART_STAGE_RATE = 60/84  # minutes per cart
    TLMD_CART_STAGE_VARIANCE = Process_Variance  # 10% variance
    TLMD_CART_HANDOFF_RATE = 60/22  # minutes per pallet
    TLMD_CART_HANDOFF_VARIANCE = Process_Variance  # 10% variance
    CART_STAGE_RATE = 2  # minutes per cart
    CART_STAGE_VARIANCE = Process_Variance  # 10% variance
    TLMD_CART_HANDOFF_RATE = 2  # minutes per cart
    TLMD_CART_HANDOFF_VARIANCE = Process_Variance  # 10% variance
    NATIONAL_CARRIER_SORT_RATE = 60/148  # minutes per package
    NATIONAL_CARRIER_SORT_VARIANCE = Process_Variance  # 10% variance
    NC_PALLET_STAGING_RATE = 60/120  # minutes per pallet
    NC_PALLET_STAGING_VARIANCE = Process_Variance  # 10% variance
    NATIONAL_CARRIER_FLUID_PICK_RATE = 1/60  # minutes per package
    NATIONAL_CARRIER_FLUID_PICK_VARIANCE = Process_Variance  # 10% variance
    NATIONAL_CARRIER_FLUID_LOAD_RATE = 60/120  # minutes per package
    NATIONAL_CARRIER_FLUID_LOAD_VARIANCE = Process_Variance  # 10% variance
    

    OUTBOUND_NC_PALLET_MAX_PACKAGES = 50  # Max packages per pallet
    PARTITION_PALLET_MAX_PACKAGES = 50  # Max packages per pallet
    TLMD_PARTITION_PALLET_MAX_PACKAGES = 50  # Max packages per pallet
    NC_PALLET_MAX_PACKAGES = 50  # Max packages per pallet
    TLMD_CART_MAX_PACKAGES = 20  # Max packages per cart
    TOTAL_PACKAGES = None  # Total packages to be processed
    TOTAL_PACKAGES_TLMD = None  # Total TLMD packages to be processed
    TOTAL_PACKAGES_NC = None  # Total National Carrier packages to be processed
    TLMD_INDUCT_TIME = None
    TLMD_STAGED_PACKAGES = None
    TLMD_PARTITION_1_PACKAGES = None
    TLMD_PARTITION_2_PACKAGES = None
    TLMD_PARTITION_3_PACKAGES = None
    TLMD_PARTITION_1_SORT_TIME = None
    TLMD_PARTITION_2_SORT_TIME = None 
    TLMD_PARTITION_3_SORT_TIME = None
    TLMD_SORTED_PACKAGES = None
    TLMD_PARTITION_1_CART_STAGE_TIME = None
    TLMD_PARTITION_2_CART_STAGE_TIME = None 
    TLMD_PARTITION_3_CART_STAGE_TIME = None
    TLMD_OUTBOUND_PACKAGES = None
    I=1
    J=1
    K=1
    PASSED_OVER_PALLETS_1 = None
    PASSED_OVER_PALLETS_2 = None
    PASSED_OVER_PALLETS_3 = None

    TOTAL_PACKAGES_UPSN = None
    TOTAL_PACKAGES_USPS = None
    TOTAL_PACKAGES_FDEG = None
    TOTAL_PACKAGES_FDE = None
    UPSN_PALLETS = None
    USPS_PALLETS = None
    FDEG_PALLETS = None
    FDE_PALLETS = None
    UPSN_SORT_TIME = None
    USPS_SORT_TIME = None
    FDEG_SORT_TIME = None
    FDE_SORT_TIME = None

    TOTAL_SHIFT_PACKAGE_CARRYOVER = None
    TLMD_PALLET_PACKAGES_CARRYOVER = None
    TLMD_1_STAGED_PALLET_CARRYOVER = None
    TLMD_2_STAGED_PALLET_CARRYOVER = None
    TLMD_3_STAGED_PALLET_CARRYOVER = None
    TLMD_INDUCT_STAGING_PALLETS_CARRYOVER = None
    TLMD_INDUCT_STAGING_PACKAGES_CARRYOVER = None
    TLMD_SPLITTER_CARRYOVER = None
    TLMD_FINAL_SORT_CARRYOVER = None
    TLMD_CART_CARRYOVER = None

    PARTITION_1_RATIO = 0.50  # Ratio of packages to go to partition 1
    PARTITION_2_RATIO = 0.35  # Ratio of packages to go to partition 2
    PARTITION_3_RATIO = 0.15  # Ratio of packages to go to partition 3

    USPS_DEPARTURE_TIME = [780]  # minutes
    UPSN_DEPARTURE_TIME = [1440]  # minutes
    FDEG_DEPARTURE_TIME = [180, 390]  # minutes
    FDE_DEPARTURE_TIME = [330]  # minutes

class Package:
    def __init__(self, tracking_number, pallet_id, scac):
        self.tracking_number = tracking_number
        self.pallet_id = pallet_id
        self.scac = scac
        self.current_queue = None

class Pallet:
    def __init__(self, env, pallet_id, packages, pkg_received_utc_ts):
        self.env = env
        self.pkg_received_utc_ts = pkg_received_utc_ts
        self.pallet_id = pallet_id
        self.packages = [Package(pkg[0], pallet_id, pkg[1]) for pkg in packages]
        self.current_queue = None
        self.remaining_packages = len(packages)  # Track remaining packages

class TLMD_Pallet:
    def __init__(self, env, pallet_id, packages, built_time):
        self.env = env
        self.built_time = built_time
        self.pallet_id = pallet_id
        self.packages = packages
        self.current_packages = len(packages)  # Track remaining packages

    def add_package(self, package):
        self.packages.append(package)
        self.current_packages = len(self.packages)  # Update the count
        print(f'Package {package.tracking_number} added to pallet {self.pallet_id} at {self.env.now}')
        print(f'Pallet currently contains {self.current_packages} packages')

class TLMD_Cart:
    def __init__(self, env, cart_id, packages, built_time):
        self.env = env
        self.built_time = built_time
        self.cart_id = cart_id
        self.packages = packages
        self.current_packages = len(packages)  # Tracks packages
    
    def add_package(self, package):
        self.packages.append(package)
        self.current_packages = len(self.packages)  # Update the count
        print(f"Package {package.tracking_number} added to cart {self.cart_id} at {self.env.now}")
        print(f'Cart currently contains {self.current_packages} packages')

class National_Carrier_Pallet:
    def __init__(self, env, pallet_id, packages, scac, built_time):
        self.env = env
        self.built_time = built_time
        self.pallet_id = pallet_id
        self.packages = packages
        self.scac = scac
        self.current_packages = len(packages)  # Track remaining packages

    def add_package(self, package):
        self.packages.append(package)
        self.current_packages = len(self.packages)  # Update the count
        print(f"Package {package.tracking_number} added to pallet {self.pallet_id} at {self.env.now}")
        print(f'Pallet currently contains {self.current_packages} packages')


def make_resources_unavailable(env, sortation_center, start, end):
    yield env.timeout(start)
    print(f'Resources unavailable at {env.now}')
    sortation_center.resources_available = False
    yield env.timeout(end - start)
    print(f'Resources available at {env.now}')
    sortation_center.resources_available = True

def plot_metrics(metrics):
    plt.figure(figsize=(12, 8))
    plt.plot(metrics['resource_utilization'])
    plt.title('util')
    plt.xlabel('Time')
    plt.ylabel('util')
    plt.legend()
    plt.show()

    for queue, lengths in metrics['queue_lengths'].items():
        plt.figure(figsize=(12, 8))
        plt.plot(lengths, label=queue)
        plt.title('Queue Length')
        plt.xlabel('Time')
        plt.ylabel('Queue Length')
        plt.legend()
        plt.show()

# %% [markdown]
# # Different Soration Center Process Classes

# %%
class Sortation_Center_Inbound:
    def __init__(self, 
                 env, 
                 pallets_df, 
                 tm_pit_unload, 
                 tm_pit_induct, 
                 tm_nonpit_split, 
                 tm_nonpit_NC, 
                 tm_nonpit_buffer, 
                 Fluid_status):
        
        self.env = env
        self.pallets_df = pallets_df
        self.tm_pit_unload = simpy.Resource(env, capacity=tm_pit_unload)
        self.tm_pit_induct = simpy.PriorityResource(env, capacity=tm_pit_induct)
        self.tm_nonpit_split = simpy.Resource(env, capacity=tm_nonpit_split)
        self.tm_nonpit_NC = simpy.PriorityResource(env, capacity=tm_nonpit_NC)
        self.tm_nonpit_buffer = simpy.PriorityResource(env, capacity=tm_nonpit_buffer)
        self.Fluid_status = Fluid_status
        self.resources_available = True

        self.USPS_flag = False
        self.UPSN_flag = False
        self.FDEG_flag = False
        self.FDE_flag = False
        self.USPS_Completed = False
        self.UPSN_Completed = False
        self.FDEG_Completed = False
        self.FDE_Completed = False

        self.queues = {
            'queue_inbound_truck': simpy.Store(self.env),
            'queue_inbound_staging': simpy.Store(self.env, capacity=200),
            'queue_induct_staging_pallets': simpy.Store(self.env, capacity=10),
            'queue_induct_staging_packages': simpy.Store(self.env),
            'queue_splitter': simpy.Store(self.env, capacity=1),
            'queue_tlmd_buffer_sort': simpy.Store(self.env, capacity=100000),
            'queue_national_carrier_sort': simpy.Store(self.env, capacity=100000),
            'queue_tlmd_pallet': simpy.Store(self.env, capacity=100000),
            'queue_tlmd_staged_pallet': simpy.Store(self.env, capacity=100000),  
            "queue_FDEG_pallet": simpy.Store(self.env),
            "queue_FDE_pallet": simpy.Store(self.env),
            "queue_USPS_pallet": simpy.Store(self.env),
            "queue_UPSN_pallet": simpy.Store(self.env), 
            'queue_FDEG_staged_pallet': simpy.Store(self.env),
            'queue_FDE_staged_pallet': simpy.Store(self.env),
            'queue_USPS_staged_pallet': simpy.Store(self.env),
            'queue_UPSN_staged_pallet': simpy.Store(self.env),
            "queue_FDEG_fluid": simpy.Store(self.env, capacity=10),
            "queue_FDE_fluid": simpy.Store(self.env, capacity=10),
            "queue_USPS_fluid": simpy.Store(self.env, capacity=10),
            "queue_UPSN_fluid": simpy.Store(self.env, capacity=10),
            'queue_FDEG_outbound_packages': simpy.Store(self.env),
            'queue_FDE_outbound_packages': simpy.Store(self.env),
            'queue_USPS_outbound_packages': simpy.Store(self.env),
            'queue_UPSN_outbound_packages': simpy.Store(self.env),
        }

        self.metrics = {
            'processing_times': [],
            'queue_lengths': {key: [] for key in self.queues.keys()},
            'resource_utilization': [],
        }

        self.all_packages_staged_time = None

    def track_metrics(self):
        while True:
            for key, queue in self.queues.items():
                self.metrics['queue_lengths'][key].append(len(queue.items))
            self.metrics['resource_utilization'].append(len(self.tm_pit_unload.queue))
            yield self.env.timeout(1)

    def schedule_arrivals(self):
        for i, row in self.pallets_df.iterrows():
            pallet = Pallet(
                self.env,
                row['Pallet'],
                row['packages'],
                row['earliest_arrival']
            )
            self.env.process(self.truck_arrival(pallet))

    def truck_arrival(self, pallet):
        yield self.env.timeout(pallet.pkg_received_utc_ts)  # Arrival time
        pallet.current_queue = 'queue_inbound_truck'
        print(f'Pallet {pallet.pallet_id} arrived at {self.env.now}')
        yield self.queues['queue_inbound_truck'].put(pallet)
        self.env.process(self.unload_truck(pallet))

    def unload_truck(self, pallet):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit
        
        with self.tm_pit_unload.request() as req:
            yield req
            yield self.queues['queue_inbound_truck'].get()
            yield self.env.timeout(G.UNLOADING_RATE)  # Unloading time
            pallet.current_queue = 'queue_inbound_staging'
            print(f'Pallet {pallet.pallet_id} unloaded at {self.env.now}')
            yield self.queues['queue_inbound_staging'].put(pallet)
            self.env.process(self.move_to_induct_staging(pallet))

    def move_to_induct_staging(self, pallet):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit

        with self.tm_pit_induct.request(priority=1) as req:  # Lower priority
            yield req
            yield self.queues['queue_inbound_staging'].get()
            yield self.env.timeout(G.INDUCT_STAGE_RATE)  # Unloading time
            pallet.current_queue = 'queue_induct_staging_pallets'
            yield self.queues['queue_induct_staging_pallets'].put(pallet)
            print(f'Pallet {pallet.pallet_id} staged for induction at {self.env.now}')
            for package in pallet.packages:
                package.current_queue = 'queue_induct_staging_packages'
                yield self.queues['queue_induct_staging_packages'].put(package)
                self.env.process(self.induct_package(package, pallet))

    def induct_package(self, package, pallet):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit
        with self.tm_pit_induct.request(priority=0) as req:  # Higher priority
            yield req
            yield self.queues['queue_induct_staging_packages'].get()
            yield self.env.timeout(G.INDUCTION_RATE)
            package.current_queue = 'queue_splitter'
            print(f'Package {package.tracking_number}, {package.scac} inducted at {self.env.now}')
            yield self.queues['queue_splitter'].put(package)
            pallet.remaining_packages -= 1  # Decrement the counter
            if pallet.remaining_packages == 0:
                # Remove the pallet from queue_induct_staging_pallets
                self.remove_pallet_from_queue(pallet)
            self.env.process(self.split_package(package))

    def remove_pallet_from_queue(self, pallet):
        # Manually search for and remove the pallet from the queue
        for i, p in enumerate(self.queues['queue_induct_staging_pallets'].items):
            if p.pallet_id == pallet.pallet_id:
                del self.queues['queue_induct_staging_pallets'].items[i]
                print(f'Pallet {pallet.pallet_id} removed from queue_induct_staging_pallets at {self.env.now}')
                break

    def split_package(self, package):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit
        with self.tm_nonpit_split.request() as req:
            yield req
            yield self.queues['queue_splitter'].get()
            if package.scac in ['UPSN', 'USPS', 'FDEG', 'FDE']:
                package.current_queue = 'queue_national_carrier_sort'
                print(f'Package {package.tracking_number} split to National Sort at {self.env.now}')
                yield self.queues['queue_national_carrier_sort'].put(package)
                self.env.process(self.national_carrier_sort(package))
            else:
                package.current_queue = 'queue_tlmd_buffer_sort'
                print(f'Package {package.tracking_number} split to TLMD Buffer at {self.env.now}')
                yield self.queues['queue_tlmd_buffer_sort'].put(package)
                self.env.process(self.tlmd_buffer_sort(package))

    def national_carrier_sort(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_national_carrier_sort"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_SORT_RATE)
            
            if package.scac in ['UPSN']:
                if not self.Fluid_status:
                    yield self.queues["queue_UPSN_pallet"].put(package)
                    self.env.process(self.check_all_UPSN_sorted())
                else:
                    yield self.queues["queue_UPSN_fluid"].put(package)
                    self.env.process(self.national_carrier_fluid_split_UPSN(package))
            elif package.scac in ['USPS']:
                if not self.Fluid_status:
                    yield self.queues["queue_USPS_pallet"].put(package)
                    self.env.process(self.check_all_USPS_sorted())
                else:
                    yield self.queues["queue_USPS_fluid"].put(package)
                    self.env.process(self.national_carrier_fluid_split_USPS(package))
            elif package.scac in ['FDEG']:
                if not self.Fluid_status:
                    yield self.queues["queue_FDEG_pallet"].put(package)
                    self.env.process(self.check_all_FDEG_sorted())
                else:
                    yield self.queues["queue_FDEG_fluid"].put(package)
                    self.env.process(self.national_carrier_fluid_split_FDEG(package))
            elif package.scac in ['FDE']:
                if not self.Fluid_status:
                    yield self.queues["queue_FDE_pallet"].put(package)
                    self.env.process(self.check_all_FDE_sorted())
                else:
                    yield self.queues["queue_FDE_fluid"].put(package)
                    self.env.process(self.national_carrier_fluid_split_FDE(package))

    def check_all_UPSN_sorted(self):
        if len(self.queues['queue_UPSN_pallet'].items) == G.TOTAL_PACKAGES_UPSN:
            print(f'All UPSN packages sorted at {self.env.now}')
            G.UPSN_SORT_TIME = self.env.now 
            self.env.process(self.NC_UPSN_pallet_build())
        else:
            yield self.env.timeout(1)
            self.env.process(self.check_all_UPSN_sorted())

    def check_all_USPS_sorted(self):
        if len(self.queues['queue_USPS_pallet'].items) == G.TOTAL_PACKAGES_USPS:
            print(f'All USPS packages sorted at {self.env.now}')
            G.USPS_SORT_TIME = self.env.now
            self.env.process(self.NC_USPS_pallet_build())
        else:
            yield self.env.timeout(1)
            self.env.process(self.check_all_USPS_sorted())

    def check_all_FDEG_sorted(self):
        if len(self.queues['queue_FDEG_pallet'].items) == G.TOTAL_PACKAGES_FDEG:
            print(f'All FDEG packages sorted at {self.env.now}')
            G.FDEG_SORT_TIME = self.env.now
            self.env.process(self.NC_FDEG_pallet_build())
        else:
            yield self.env.timeout(1)
            self.env.process(self.check_all_FDEG_sorted())

    def check_all_FDE_sorted(self):
        if len(self.queues['queue_FDE_pallet'].items) == G.TOTAL_PACKAGES_FDE:
            print(f'All FDE packages sorted at {self.env.now}')
            G.FDE_SORT_TIME = self.env.now
            self.env.process(self.NC_FDE_pallet_build())
        else:
            yield self.env.timeout(1)
            self.env.process(self.check_all_FDE_sorted())

     

    def NC_UPSN_pallet_build(self):
        UPSN_pallets = math.ceil(G.TOTAL_PACKAGES_UPSN / G.NC_PALLET_MAX_PACKAGES)
        print(f'UPSN: {UPSN_pallets} pallets')
        G.UPSN_PALLETS = UPSN_pallets

        def create_NC_pallets(NC_packages, NC_pallets, queue_name, staged_queue_name, scac):
            with self.tm_nonpit_NC.request(priority=0) as req:
                yield req
                remaining_packages = NC_packages
            
                for pallet_num in range(NC_pallets):
                    pallet_packages = []
                    packages_for_this_pallet = min(G.NC_PALLET_MAX_PACKAGES, remaining_packages)
                    
                    for _ in range(packages_for_this_pallet):
                        pkg = yield self.queues[queue_name].get()
                        pallet_packages.append(pkg)
                        yield self.env.timeout(0)
                    
                    pallet = National_Carrier_Pallet(self.env, f'Pallet_{G.K}', pallet_packages, scac, self.env.now)
                    G.K += 1
                    print(f'NC_{scac}, {pallet.pallet_id} created with {len(pallet_packages)} packages at {self.env.now}')
                    
                    yield self.queues[staged_queue_name].put(pallet)
                    yield self.env.timeout(G.NC_PALLET_STAGING_RATE)
                    
                    remaining_packages -= packages_for_this_pallet

        yield self.env.process(create_NC_pallets(G.TOTAL_PACKAGES_UPSN, UPSN_pallets, 'queue_UPSN_pallet', 'queue_UPSN_staged_pallet','UPSN'))
        self.UPSN_Completed = True

    def NC_USPS_pallet_build(self):
        USPS_pallets = math.ceil(G.TOTAL_PACKAGES_USPS / G.NC_PALLET_MAX_PACKAGES)
        print(f'USPS: {USPS_pallets} pallets')
        G.USPS_PALLETS = USPS_pallets

        def create_NC_pallets(NC_packages, NC_pallets, queue_name, staged_queue_name, scac):
            with self.tm_nonpit_NC.request(priority=0) as req:
                yield req
                remaining_packages = NC_packages
            
                for pallet_num in range(NC_pallets):
                    pallet_packages = []
                    packages_for_this_pallet = min(G.NC_PALLET_MAX_PACKAGES, remaining_packages)
                    
                    for _ in range(packages_for_this_pallet):
                        pkg = yield self.queues[queue_name].get()
                        pallet_packages.append(pkg)
                        yield self.env.timeout(0)
                    
                    pallet = National_Carrier_Pallet(self.env, f'Pallet_{G.K}', pallet_packages, scac, self.env.now)
                    G.K += 1
                    print(f'NC_{scac}, {pallet.pallet_id} created with {len(pallet_packages)} packages at {self.env.now}')
                    
                    yield self.queues[staged_queue_name].put(pallet)
                    yield self.env.timeout(G.NC_PALLET_STAGING_RATE)
                    
                    remaining_packages -= packages_for_this_pallet

        yield self.env.process(create_NC_pallets(G.TOTAL_PACKAGES_USPS, USPS_pallets, 'queue_USPS_pallet', 'queue_USPS_staged_pallet','USPS'))
        self.USPS_Completed = True

    def NC_FDEG_pallet_build(self):
        FDEG_pallets = math.ceil(G.TOTAL_PACKAGES_FDEG / G.NC_PALLET_MAX_PACKAGES)
        print(f'FDEG: {FDEG_pallets} pallets')
        G.FDEG_PALLETS = FDEG_pallets

        def create_NC_pallets(NC_packages, NC_pallets, queue_name, staged_queue_name, scac):
            with self.tm_nonpit_NC.request(priority=0) as req:
                yield req
                remaining_packages = NC_packages
            
                for pallet_num in range(NC_pallets):
                    pallet_packages = []
                    packages_for_this_pallet = min(G.NC_PALLET_MAX_PACKAGES, remaining_packages)
                    
                    for _ in range(packages_for_this_pallet):
                        pkg = yield self.queues[queue_name].get()
                        pallet_packages.append(pkg)
                        yield self.env.timeout(0)
                    
                    pallet = National_Carrier_Pallet(self.env, f'Pallet_{G.K}', pallet_packages, scac, self.env.now)
                    G.K += 1
                    print(f'NC_{scac}, {pallet.pallet_id} created with {len(pallet_packages)} packages at {self.env.now}')
                    
                    yield self.queues[staged_queue_name].put(pallet)
                    yield self.env.timeout(G.NC_PALLET_STAGING_RATE)
                    
                    remaining_packages -= packages_for_this_pallet


        yield self.env.process(create_NC_pallets(G.TOTAL_PACKAGES_FDEG, FDEG_pallets, 'queue_FDEG_pallet', 'queue_FDEG_staged_pallet','FDEG'))
        self.FDEG_Completed = True

    def NC_FDE_pallet_build(self):
        FDE_pallets = math.ceil(G.TOTAL_PACKAGES_FDE / G.NC_PALLET_MAX_PACKAGES)
        print(f'FDE: {FDE_pallets} pallets')
        G.FDE_PALLETS = FDE_pallets

        def create_NC_pallets(NC_packages, NC_pallets, queue_name, staged_queue_name, scac):
            with self.tm_nonpit_NC.request(priority=0) as req:
                yield req
                remaining_packages = NC_packages
            
                for pallet_num in range(NC_pallets):
                    pallet_packages = []
                    packages_for_this_pallet = min(G.NC_PALLET_MAX_PACKAGES, remaining_packages)
                    
                    for _ in range(packages_for_this_pallet):
                        pkg = yield self.queues[queue_name].get()
                        pallet_packages.append(pkg)
                        yield self.env.timeout(0)
                    
                    pallet = National_Carrier_Pallet(self.env, f'Pallet_{G.K}', pallet_packages, scac, self.env.now)
                    G.K += 1
                    print(f'NC_{scac}, {pallet.pallet_id} created with {len(pallet_packages)} packages at {self.env.now}')
                    
                    yield self.queues[staged_queue_name].put(pallet)
                    yield self.env.timeout(G.NC_PALLET_STAGING_RATE)
                    
                    remaining_packages -= packages_for_this_pallet

        yield self.env.process(create_NC_pallets(G.TOTAL_PACKAGES_FDE, FDE_pallets, 'queue_FDE_pallet', 'queue_FDE_staged_pallet','FDE'))
        self.FDE_Completed = True

########################################################
##### Begin National Carrier Fluid Load Process#########
########################################################

    def national_carrier_fluid_split_UPSN(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_UPSN_fluid"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_PICK_RATE)
            print(f"Package {package.tracking_number} sorted to UPSN fluid at {self.env.now}")
            yield self.queues["queue_UPSN_truck"].put(package)
            self.env.process(self.national_carrier_fluid_load_UPSN(package))

    def national_carrier_fluid_load_UPSN(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_UPSN_truck"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_LOAD_RATE)
            print(f"Package {package.tracking_number} fulid loaded to UPSN at {self.env.now}")
            yield self.queues["queue_UPSN_Outbound"].put(package)


    def national_carrier_fluid_split_USPS(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_USPS_fluid"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_PICK_RATE)
            print(f"Package {package.tracking_number} sorted to USPS fluid at {self.env.now}")
            yield self.queues["queue_USPS_truck"].put(package)
            self.env.process(self.national_carrier_fluid_load_USPS(package))

    def national_carrier_fluid_load_USPS(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_USPS_truck"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_LOAD_RATE)
            print(f"Package {package.tracking_number} fulid loaded to USPS at {self.env.now}")
            yield self.queues["queue_USPS_Outbound"].put(package)


    def national_carrier_fluid_split_FDEG(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_FDEG_fluid"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_PICK_RATE)
            print(f"Package {package.tracking_number} sorted to FDEG fluid at {self.env.now}")
            yield self.queues["queue_FDEG_truck"].put(package)
            self.env.process(self.national_carrier_fluid_load_FDEG(package))

    def national_carrier_fluid_load_FDEG(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_FDEG_truck"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_LOAD_RATE)
            print(f"Package {package.tracking_number} fulid loaded to FDEG at {self.env.now}")
            yield self.queues["queue_FDEG_Outbound"].put(package)


    def national_carrier_fluid_split_FDE(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_FDE_fluid"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_PICK_RATE)
            print(f"Package {package.tracking_number} sorted to FDE fluid at {self.env.now}")
            yield self.queues["queue_FDE_truck"].put(package)
            self.env.process(self.national_carrier_fluid_load_FDE(package))

    def national_carrier_fluid_load_FDE(self, package):
        with self.tm_nonpit_NC.request(priority=1) as req:
            yield req
            yield self.queues["queue_FDE_truck"].get()
            yield self.env.timeout(G.NATIONAL_CARRIER_FLUID_LOAD_RATE)
            print(f"Package {package.tracking_number} fulid loaded to FDE at {self.env.now}")
            yield self.queues["queue_FDE_Outbound"].put(package)


    ########################################################
    ############## Begin TLMD Sort Process #################
    ########################################################
    
    # this will need to be updated to include the logic associated with the different partitions
    def tlmd_buffer_sort(self, package):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit

        # Check if all completion flags are true
        if self.USPS_Completed and self.UPSN_Completed and self.FDEG_Completed and self.FDE_Completed:
            # Request from either tm_nonpit_buffer or tm_nonpit_NC
            with self.tm_nonpit_buffer.request(priority=1) as req:
                yield req
                yield self.queues['queue_tlmd_buffer_sort'].get()
                yield self.env.timeout(G.TLMD_BUFFER_SORT_RATE)
                print(f'Package {package.tracking_number} sorted to TLMD Buffer using tm_nonpit_buffer at {self.env.now}')
                self.check_all_packages_staged()
            
            # Optional: Request from tm_nonpit_NC if needed
            with self.tm_nonpit_NC.request(priority=1) as nc_req:
                yield nc_req
                yield self.queues['queue_tm_nonpit_NC'].get()
                yield self.env.timeout(G.TLMD_BUFFER_SORT_RATE)
                print(f'Package {package.tracking_number} sorted to TLMD Buffer using tm_nonpit_NC at {self.env.now}')
                self.check_all_packages_staged()

        else:
            # Only tm_nonpit_buffer is available
            with self.tm_nonpit_buffer.request(priority=1) as req:
                yield req
                print(f'Using tm_nonpit_buffer for sorting package {package.tracking_number} at {self.env.now}')
                yield self.queues['queue_tlmd_buffer_sort'].get()
                yield self.env.timeout(G.TLMD_BUFFER_SORT_RATE)
                print(f'Package {package.tracking_number} sorted to TLMD Buffer using tm_nonpit_buffer at {self.env.now}')
                self.check_all_packages_staged()


       
    #determine if queue_tlmd_staged_pallet holds the same number of packages as total_packages and if so, record the time
    def check_all_packages_staged(self):
        if len(self.queues['queue_tlmd_pallet'].items) == G.TOTAL_PACKAGES_TLMD:
            self.all_packages_staged_time = self.env.now
            G.TLMD_INDUCT_TIME = self.all_packages_staged_time
            print(f'All packages staged at {self.all_packages_staged_time}')
            G.TLMD_STAGED_PACKAGES = self.queues['queue_tlmd_pallet'].items

    def run_simulation(self, until):
        ############################
        #Add mechanism to capture the remaining packages due to inadequate time to process all packages
        if self.env.now == until:
            print('Simulation ended due to time limit')
            self.env.exit()
        return self.env.timeout(until)


class Sortation_Center_TLMD:
    def __init__(self, 
                env, 
                packages_df, 
                tm_TLMD_induct,
                tm_TLMD_picker,
                tm_TLMD_sort, 
                ):
        
        self.env = env
        self.packages_df = packages_df
        self.tm_TLMD_induct = simpy.PriorityResource(env, capacity=tm_TLMD_induct)
        self.tm_TLMD_picker = simpy.Resource(env, capacity=tm_TLMD_picker)
        self.tm_TLMD_sort = simpy.Resource(env, capacity=tm_TLMD_sort)
        self.resources_available = True


        self.partition_1_flag = False
        self.partition_2_flag = False
        self.partition_3_flag = False
        self.dedicate_to_cart_staging = False

        self.queues = {
                        'queue_tlmd_pallet_packages': simpy.Store(env),
                        'queue_tlmd_1_staged_pallet': simpy.Store(env),
                        'queue_tlmd_2_staged_pallet': simpy.Store(env),
                        'queue_tlmd_3_staged_pallet': simpy.Store(env),
                        'queue_tlmd_induct_staging_pallets' : simpy.Store(env, capacity=6),
                        'queue_tlmd_induct_staging_packages' : simpy.Store(env),
                        'queue_tlmd_splitter' : simpy.Store(env),
                        'queue_tlmd_final_sort' : simpy.Store(env),
                        'queue_tlmd_cart' : simpy.Store(env)  
                        }

        for item in G.TLMD_STAGED_PACKAGES:
            self.queues['queue_tlmd_pallet_packages'].put(item)

        self.metrics = {
            'processing_times': [],
            'queue_lengths': {key: [] for key in self.queues.keys()},
            'resource_utilization': [],
            }

        self.all_packages_staged_time = None

    def track_metrics(self):
        while True:
            for key, queue in self.queues.items():
                self.metrics['queue_lengths'][key].append(len(queue.items))
            yield self.env.timeout(1)


    #Generate the stock of packages that resulted from the previous simulation.

    def TLMD_pallet_build(self):
    # Calculate the number of packages in each partition
        partition_1_packages = round(G.PARTITION_1_RATIO * G.TOTAL_PACKAGES_TLMD)
        partition_2_packages = round(G.PARTITION_2_RATIO * G.TOTAL_PACKAGES_TLMD)
        partition_3_packages = round(G.PARTITION_3_RATIO * G.TOTAL_PACKAGES_TLMD)

        G.TLMD_PARTITION_1_PACKAGES = partition_1_packages
        G.TLMD_PARTITION_2_PACKAGES = partition_2_packages
        G.TLMD_PARTITION_3_PACKAGES = partition_3_packages
    
        
        print(f'Partition 1: {partition_1_packages} packages')
        print(f'Partition 2: {partition_2_packages} packages')
        print(f'Partition 3: {partition_3_packages} packages')
        print(f'Total packages: {partition_1_packages + partition_2_packages + partition_3_packages}')
        
        # Handle any rounding discrepancies
        if partition_1_packages + partition_2_packages + partition_3_packages != G.TOTAL_PACKAGES_TLMD:
            partition_1_packages += G.TOTAL_PACKAGES_TLMD - (partition_1_packages + partition_2_packages + partition_3_packages)
            print(f'Adjusted Partition 1: {partition_1_packages} packages')

        # Calculate the number of pallets needed for each partition
        partition_1_pallets = math.ceil(partition_1_packages / G.TLMD_PARTITION_PALLET_MAX_PACKAGES)
        partition_2_pallets = math.ceil(partition_2_packages / G.TLMD_PARTITION_PALLET_MAX_PACKAGES)
        partition_3_pallets = math.ceil(partition_3_packages / G.TLMD_PARTITION_PALLET_MAX_PACKAGES)

        # Function to create pallets for a given partition
        def create_pallets(partition_packages, partition_pallets, queue_name, staged_queue_name):
            remaining_packages = partition_packages
            
            for pallet_num in range(partition_pallets):
                pallet_packages = []
                
                # Calculate how many packages should go on this pallet (handle last pallet separately)
                packages_for_this_pallet = min(G.TLMD_PARTITION_PALLET_MAX_PACKAGES, remaining_packages)
                
                # Fetch exactly the required number of packages from the queue
                for _ in range(packages_for_this_pallet):
                    pkg = yield self.queues[queue_name].get()
                    pallet_packages.append(pkg)
                    yield self.env.timeout(0)
                
                # Create and stage the pallet
                pallet = TLMD_Pallet(self.env, f'Pallet_{G.I}', pallet_packages, self.env.now)
                G.I += 1
                print(f'TLMD {pallet.pallet_id} created with {len(pallet_packages)} packages at {self.env.now}')
                
                # Move pallet to the staged queue
                yield self.queues[staged_queue_name].put(pallet)
                yield self.env.timeout(0)
                self.env.process(self.feed_TLMD_induct_staging(pallet))
                
                # Reduce remaining packages count
                remaining_packages -= packages_for_this_pallet

        # Create pallets for each partition
        yield self.env.process(create_pallets(partition_1_packages, partition_1_pallets, 'queue_tlmd_pallet_packages', 'queue_tlmd_1_staged_pallet'))
        yield self.env.process(create_pallets(partition_2_packages, partition_2_pallets, 'queue_tlmd_pallet_packages', 'queue_tlmd_2_staged_pallet'))
        yield self.env.process(create_pallets(partition_3_packages, partition_3_pallets, 'queue_tlmd_pallet_packages', 'queue_tlmd_3_staged_pallet'))



    def feed_TLMD_induct_staging(self,pallet):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit
        with self.tm_TLMD_induct.request(priority=1) as req:  # Lower priority
            yield req
            if len(self.queues['queue_tlmd_1_staged_pallet'].items) > 0:
                yield self.queues['queue_tlmd_1_staged_pallet'].get()
            elif len(self.queues['queue_tlmd_2_staged_pallet'].items) > 0:
                yield self.queues['queue_tlmd_2_staged_pallet'].get()
            else:
                yield self.queues['queue_tlmd_3_staged_pallet'].get()

            yield self.env.timeout(G.TLMD_INDUCT_STAGE_RATE)  # Unloading time
            pallet.current_queue = 'queue_tlmd_induct_staging_pallets'
            yield self.queues['queue_tlmd_induct_staging_pallets'].put(pallet)
            print(f'Pallet {pallet.pallet_id} staged for TLMD induction at {self.env.now}')
            for package in pallet.packages:
                package.current_queue = 'queue_tlmd_induct_staging_packages'
                yield self.queues['queue_tlmd_induct_staging_packages'].put(package)
                self.env.process(self.tlmd_induct_package(package, pallet))


    def tlmd_induct_package(self, package, pallet):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit
        with self.tm_TLMD_induct.request(priority=0) as req:  # Higher priority
            yield req
            yield self.queues['queue_tlmd_induct_staging_packages'].get()
            yield self.env.timeout(G.INDUCTION_RATE)
            package.current_queue = 'queue_tlmd_splitter'
            print(f'Package {package.tracking_number}, {package.scac} inducted at TLMD at {self.env.now}')
            yield self.queues['queue_tlmd_splitter'].put(package)
            pallet.current_packages -= 1  # Decrement the counter
            if pallet.current_packages == 0:
                # Remove the pallet from queue_induct_staging_pallets
                self.tlmd_remove_pallet_from_queue(pallet)
            self.env.process(self.tlmd_lane_pickoff(package))

    def tlmd_remove_pallet_from_queue(self, pallet):
        # Manually search for and remove the pallet from the queue
        for i, p in enumerate(self.queues['queue_tlmd_induct_staging_pallets'].items):
            if p.pallet_id == pallet.pallet_id:
                del self.queues['queue_tlmd_induct_staging_pallets'].items[i]
                print(f'Pallet {pallet.pallet_id} removed from queue_tlmd_induct_staging_pallets at {self.env.now}')
                break

    #Will need to include logic to split based on the different lanes
    
    def tlmd_lane_pickoff(self, package):
        while not self.resources_available:
            yield self.env.timeout(1)  # Check every 1 time unit
        with self.tm_TLMD_picker.request() as req:
            yield req
            yield self.queues['queue_tlmd_splitter'].get()
            yield self.env.timeout(G.SPLITTER_RATE)
            package.current_queue = 'queue_tlmd_final_sort'
            print(f'Package {package.tracking_number} split to TLMD Final Sort at {self.env.now}')
            yield self.queues['queue_tlmd_final_sort'].put(package)
            self.env.process(self.tlmd_final_sort(package))

    # will need to include logic to sort to specific carts based on lane designation
    def tlmd_final_sort(self, package):
        while not self.resources_available or self.dedicate_to_cart_staging:
            yield self.env.timeout(1)  # Check every 1 time unit
        with self.tm_TLMD_sort.request() as req:
            yield req
            yield self.queues['queue_tlmd_final_sort'].get()
            yield self.env.timeout(G.TLMD_BUFFER_SORT_RATE)
            print(f'Package {package.tracking_number} sorted to TLMD Cart at {self.env.now}')
            yield self.queues['queue_tlmd_cart'].put(package)
            print(f'Total packages sorted: {len(self.queues["queue_tlmd_cart"].items)}')
            self.check_all_TLMD_sorted()

    def check_all_TLMD_sorted(self):
        if (
            not self.partition_1_flag
            and len(self.queues['queue_tlmd_1_staged_pallet'].items) == 0
            and len(self.queues['queue_tlmd_cart'].items) > G.TLMD_PARTITION_1_PACKAGES
        ):
                all_packages_staged_time_1 = self.env.now
                G.TLMD_PARTITION_1_SORT_TIME = all_packages_staged_time_1
                print(f'All partition 1 packages sorted at {all_packages_staged_time_1}')
                self.partition_1_flag = True  # Mark this partition as handled

        # Check for partition 2 only if partition 1 is done
        elif (
            not self.partition_2_flag
            and self.partition_1_flag  # Ensure partition 1 is done
            and len(self.queues['queue_tlmd_2_staged_pallet'].items) == 0
            and len(self.queues['queue_tlmd_cart'].items) > G.TLMD_PARTITION_2_PACKAGES + G.TLMD_PARTITION_1_PACKAGES
        ):
            all_packages_staged_time_2 = self.env.now
            G.TLMD_PARTITION_2_SORT_TIME = all_packages_staged_time_2
            print(f'All partition 2 packages sorted at {all_packages_staged_time_2}')
            self.partition_2_flag = True  # Mark this partition as handled

        # Check for partition 3 only if partition 2 is done
        elif (
            not self.partition_3_flag
            and self.partition_2_flag  # Ensure partition 2 is done
            and len(self.queues['queue_tlmd_cart'].items) >= G.TLMD_PARTITION_3_PACKAGES + G.TLMD_PARTITION_2_PACKAGES + G.TLMD_PARTITION_1_PACKAGES
        ):
            all_packages_staged_time_3 = self.env.now
            G.TLMD_PARTITION_3_SORT_TIME = all_packages_staged_time_3
            print(f'All partition 3 packages sorted at {all_packages_staged_time_3}')
            self.partition_3_flag = True  # Mark this partition as handled

        # Check if all partitions are done
        if self.partition_1_flag and self.partition_2_flag and self.partition_3_flag:
            G.TLMD_SORTED_PACKAGES = self.queues['queue_tlmd_cart'].items
            print(f'All {len(G.TLMD_SORTED_PACKAGES)} TLMD packages sorted at {self.env.now}')
        
        else:
            G.PASSED_OVER_PALLETS_1 = self.queues['queue_tlmd_1_staged_pallet'].items
            G.PASSED_OVER_PALLETS_2 = self.queues['queue_tlmd_2_staged_pallet'].items
            G.PASSED_OVER_PALLETS_3 = self.queues['queue_tlmd_3_staged_pallet'].items
            G.TLMD_PALLET_PACKAGES_CARRYOVER = self.queues['queue_tlmd_pallet_packages']
            G.TLMD_1_STAGED_PALLET_CARRYOVER = self.queues['queue_tlmd_1_staged_pallet']
            G.TLMD_2_STAGED_PALLET_CARRYOVER = self.queues['queue_tlmd_2_staged_pallet']
            G.TLMD_3_STAGED_PALLET_CARRYOVER = self.queues['queue_tlmd_3_staged_pallet']
            G.TLMD_INDUCT_STAGING_PALLETS_CARRYOVER = self.queues['queue_tlmd_induct_staging_pallets']
            G.TLMD_INDUCT_STAGING_PACKAGES_CARRYOVER = self.queues['queue_tlmd_induct_staging_packages']
            G.TLMD_SPLITTER_CARRYOVER = self.queues['queue_tlmd_splitter']
            G.TLMD_FINAL_SORT_CARRYOVER = self.queues['queue_tlmd_final_sort']
            G.TLMD_CART_CARRYOVER = self.queues['queue_tlmd_cart'] 
            
            
    def run_simulation(self, until):
        return self.env.timeout(until)

class Sortation_Center_TLMD_Stage:
    def __init__(self, 
                env, 
                tm_TLMD_stage, 
                tm_TLMD_handoff,
                ):
        
        self.env = env
        self.tm_TLMD_stage = simpy.Resource(env, capacity=tm_TLMD_stage)
        self.tm_TLMD_handoff = simpy.Resource(env, capacity=tm_TLMD_handoff)
        self.resources_available = True


        self.queues = {
                        'queue_tlmd_cart': simpy.Store(env),
                        'queue_tlmd_1_cart' : simpy.Store(env),
                        'queue_tlmd_2_cart' : simpy.Store(env),
                        'queue_tlmd_3_cart' : simpy.Store(env),  
                        'queue_tlmd_cart_1_staging' : simpy.Store(env),
                        'queue_tlmd_cart_2_staging' : simpy.Store(env),
                        'queue_tlmd_cart_3_staging' : simpy.Store(env),
                        'queue_tlmd_cart_handoff' : simpy.Store(env),
                        }
        print("test 4")
        for item in G.TLMD_SORTED_PACKAGES:
            self.queues['queue_tlmd_cart'].put(item)

        self.metrics = {
            'processing_times': [],
            'queue_lengths': {key: [] for key in self.queues.keys()},
            'resource_utilization': [],
            }

        self.all_packages_staged_time = None

    def track_metrics(self):
        while True:
            for key, queue in self.queues.items():
                self.metrics['queue_lengths'][key].append(len(queue.items))
            yield self.env.timeout(1)


    #Generate the stock of packages that resulted from the previous simulation.

    def TLMD_cart_build(self):
        partition_1_packages = G.TLMD_PARTITION_1_PACKAGES
        partition_2_packages = G.TLMD_PARTITION_2_PACKAGES
        partition_3_packages = G.TLMD_PARTITION_3_PACKAGES
    
        
        print(f'Partition 1: {partition_1_packages} packages')
        print(f'Partition 2: {partition_2_packages} packages')
        print(f'Partition 3: {partition_3_packages} packages')
        print(f'Total packages: {partition_1_packages + partition_2_packages + partition_3_packages}')
        
        # Calculate the number of pallets needed for each partition
        partition_1_carts = math.ceil(partition_1_packages / G.TLMD_CART_MAX_PACKAGES)
        partition_2_carts = math.ceil(partition_2_packages / G.TLMD_CART_MAX_PACKAGES)
        partition_3_carts = math.ceil(partition_3_packages / G.TLMD_CART_MAX_PACKAGES)



        # Function to create pallets for a given partition
        def create_carts(partition_packages, partition_carts, queue_name, staged_queue_name):
            remaining_packages = partition_packages
            
            for cart_num in range(partition_carts):
                cart_packages = []
                
                # Calculate how many packages should go on this pallet (handle last pallet separately)
                packages_for_this_cart = min(G.TLMD_CART_MAX_PACKAGES, remaining_packages)
                
                # Fetch exactly the required number of packages from the queue
                for _ in range(packages_for_this_cart):
                    pkg = yield self.queues[queue_name].get()
                    cart_packages.append(pkg)
                    yield self.env.timeout(0)
                
                # Create and stage the pallet
                cart = TLMD_Cart(self.env, f'Cart_{G.J}', cart_packages, self.env.now)
                G.J += 1
                print(f'TLMD {cart.cart_id} created with {len(cart_packages)} packages at {self.env.now}')
                
                # Move pallet to the staged queue
                yield self.queues[staged_queue_name].put(cart)
                yield self.env.timeout(0)
                self.env.process(self.cart_staging(cart))
                
                # Reduce remaining packages count
                remaining_packages -= packages_for_this_cart

        # Create pallets for each partition
        yield self.env.process(create_carts(partition_1_packages, partition_1_carts, 'queue_tlmd_cart', 'queue_tlmd_1_cart'))
        yield self.env.process(create_carts(partition_2_packages, partition_2_carts, 'queue_tlmd_cart', 'queue_tlmd_2_cart'))
        yield self.env.process(create_carts(partition_3_packages, partition_3_carts, 'queue_tlmd_cart', 'queue_tlmd_3_cart'))


    def cart_staging(self,cart):
        while not self.resources_available:
            yield self.env.timeout(1)
        with self.tm_TLMD_stage.request() as req:
            yield req
            if len(self.queues['queue_tlmd_1_cart'].items) > 0:
                yield self.queues['queue_tlmd_1_cart'].get()
                yield self.env.timeout(G.CART_STAGE_RATE)
                cart.current_queue = 'queue_tlmd_cart_1_staging'
                print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
                yield self.queues['queue_tlmd_cart_1_staging'].put(cart)
                if len(self.queues['queue_tlmd_1_cart'].items) == 0:
                    G.TLMD_PARTITION_1_CART_STAGE_TIME = self.env.now
                    print(f'Partition 1 staged for TLMD handoff at {self.env.now}')
            elif len(self.queues['queue_tlmd_2_cart'].items) > 0:
                yield self.queues['queue_tlmd_2_cart'].get()
                yield self.env.timeout(G.CART_STAGE_RATE)
                cart.current_queue = 'queue_tlmd_cart_2_staging'
                print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
                yield self.queues['queue_tlmd_cart_2_staging'].put(cart)
                if len(self.queues['queue_tlmd_2_cart'].items) == 0:
                    G.TLMD_PARTITION_2_CART_STAGE_TIME = self.env.now
                    print(f'Partition 2 staged for TLMD handoff at {self.env.now}')
            else:
                yield self.queues['queue_tlmd_3_cart'].get()
                yield self.env.timeout(G.CART_STAGE_RATE)
                cart.current_queue = 'queue_tlmd_cart_3_staging'
                print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
                if len(self.queues['queue_tlmd_3_cart'].items) == 0:
                    G.TLMD_PARTITION_3_CART_STAGE_TIME = self.env.now
                    print(f'Partition 3 staged for TLMD handoff at {self.env.now}')
            
            #self.env.process(self.tlmd_cart_handoff(cart))
####################################################################################################################
#This function is requied to be written still
###

#####################################################################################################################
    def tlmd_cart_handoff(self, cart):
        while not self.resources_available:
            yield self.env.timeout(1)
        with self.tm_TLMD_handoff.request() as req:
            yield req
            yield self.queues['queue_tlmd_cart_staging'].get()
            yield self.env.timeout(G.TLMD_CART_HANDOFF_RATE)
            print(f'Cart {cart.cart_id} handed off to outbound at {self.env.now}')
            yield self.queues['queue_tlmd_outbound_packages'].put(cart)
            self.check_all_TLMD_handoff()




    """
    def cart_staging(self, cart):
        while not self.resources_available:
            yield self.env.timeout(1)
        with self.tm_TLMD_stage.request(priority=1) as req:
            yield req
            if len(self.queues['queue_tlmd_1_cart'].items) > 0:
                yield self.queues['queue_tlmd_1_cart'].get()
                G.TLMD_PARTITION_1_CART_STAGE_TIME = self.env.now
                print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
            elif len(self.queues['queue_tlmd_2_cart'].items) > 0:
                yield self.queues['queue_tlmd_2_cart'].get()
                G.TLMD_PARTITION_2_CART_STAGE_TIME = self.env.now
                print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
            else:
                yield self.queues['queue_tlmd_3_cart'].get()
                G.TLMD_PARTITION_3_CART_STAGE_TIME = self.env.now
                print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
            yield self.env.timeout(G.CART_STAGE_RATE)  # Unloading time
            cart.current_queue = 'queue_tlmd_cart_staging'
            yield self.queues['queue_tlmd_cart_staging'].put(cart)
            print(f'Cart {cart.cart_id} staged for TLMD handoff at {self.env.now}')
            #self.env.process(self.tlmd_cart_handoff(cart))
            self.dedicate_to_cart_staging = False  # Reset flag after staging
    """
    def run_simulation(self, until):
        return self.env.timeout(until)

    
###################################################
######## End Sortation Induct Process #############
###################################################

# %%
def setup_simulation(day_pallets, 
                     tm_pit_unload, 
                     tm_pit_induct, 
                     tm_nonpit_split, 
                     tm_nonpit_NC, 
                     tm_nonpit_buffer, 
                     unavailable_periods=None):

    total_TMs_day = tm_pit_unload + tm_pit_induct + tm_nonpit_split + tm_nonpit_NC + tm_nonpit_buffer
    total_packages = sum([len(row['packages']) for i, row in day_pallets.iterrows()])
    all_packages = [pkg for sublist in pallet_info['packages'] for pkg in sublist]
    total_packages_NC = len([pkg for pkg in all_packages if pkg[1] in ['UPSN', 'USPS', 'FDEG', 'FDE']])
    total_packages_UPSN = len([pkg for pkg in all_packages if pkg[1] in ['UPSN']])
    total_packages_USPS = len([pkg for pkg in all_packages if pkg[1] in ['USPS']])
    total_packages_FDEG = len([pkg for pkg in all_packages if pkg[1] in ['FDEG']])
    total_packages_FDE = len([pkg for pkg in all_packages if pkg[1] in ['FDE']])

    total_packages_TLMD = total_packages - total_packages_NC

    print(f'Total Inbound Packages: {total_packages}')
    print(f'Total Inbound TLMD Packages: {total_packages_TLMD}')
    print(f'Total Inbound NC Packages: {total_packages_NC}')
    print(f'Total Inbound UPSN Packages: {total_packages_UPSN}')
    print(f'Total Inbound USPS Packages: {total_packages_USPS}')
    print(f'Total Inbound FDEG Packages: {total_packages_FDEG}')
    print(f'Total Inbound FDE Packages: {total_packages_FDE}')


    G.TOTAL_PACKAGES = total_packages
    G.TOTAL_PACKAGES_TLMD = total_packages_TLMD
    G.TOTAL_PACKAGES_NC = total_packages_NC 
    G.TOTAL_PACKAGES_UPSN = total_packages_UPSN
    G.TOTAL_PACKAGES_USPS = total_packages_USPS
    G.TOTAL_PACKAGES_FDEG = total_packages_FDEG
    G.TOTAL_PACKAGES_FDE = total_packages_FDE
    

    Fluid_status = total_TMs_day >= 20 and total_packages >= 10000

    env = simpy.Environment()

    sortation_center = Sortation_Center_Inbound(
        env, 
        day_pallets, 
        tm_pit_unload, 
        tm_pit_induct, 
        tm_nonpit_split, 
        tm_nonpit_NC, 
        tm_nonpit_buffer, 
        Fluid_status
    )

    # Start tracking metrics and schedule arrivals
    env.process(sortation_center.track_metrics())
    sortation_center.schedule_arrivals()

    # Set up unavailable periods for resources
    if unavailable_periods:
        for start, end in unavailable_periods:
            env.process(make_resources_unavailable(env, sortation_center, start, end))

    return env, sortation_center


def setup_simulation_2(tlmd_staged_packages, 
                    tm_TLMD_induct,
                    tm_TLMD_picker,
                    tm_TLMD_sort,
                     unavailable_periods=None):


    total_packages = len(tlmd_staged_packages)
    print(f'Total Packages to sort: {total_packages}')
   
    env = simpy.Environment()

    sortation_center = Sortation_Center_TLMD(
        env, 
        tlmd_staged_packages,
        tm_TLMD_induct,
        tm_TLMD_picker,
        tm_TLMD_sort,
    )

    # Start tracking metrics and schedule arrivals
    env.process(sortation_center.track_metrics())
    env.process(sortation_center.TLMD_pallet_build())

    # Set up unavailable periods for resources
    if unavailable_periods:
        for start, end in unavailable_periods:
            env.process(make_resources_unavailable(env, sortation_center, start, end))

    return env, sortation_center


def setup_simulation_3(tm_TLMD_stage,
                        tm_TLMD_handoff,
                        unavailable_periods=None):


    total_packages = len(G.TLMD_SORTED_PACKAGES)
    env = simpy.Environment()
    
    sortation_center = Sortation_Center_TLMD_Stage(
        env, 
        tm_TLMD_stage,
        tm_TLMD_handoff 
    )

    # Start tracking metrics and schedule arrivals
    env.process(sortation_center.track_metrics())
    env.process(sortation_center.TLMD_cart_build())

    # Set up unavailable periods for resources
    if unavailable_periods:
        for start, end in unavailable_periods:
            env.process(make_resources_unavailable(env, sortation_center, start, end))
    return env, sortation_center

# %%
if __name__ == '__main__':
    # Create a sample dataframe for package arrival data
    csv_path = 'package_arrivals721.csv'
    df = pd.read_csv(csv_path)

    pallet_info = df.groupby('Pallet').agg(
        num_packages=('package_tracking_number', 'count'),
        earliest_arrival=('pkg_received_utc_ts', 'min'),
        packages=('package_tracking_number', lambda x: list(zip(x, df.loc[x.index, 'scac'])))
    ).reset_index()
    
    nights_total_tm = 19

    #DAYS INBOUND INDUCT ALLOCATION
    night_tm_pit_unload = 2 
    night_tm_pit_induct = 4
    night_tm_nonpit_split = 1
    night_tm_nonpit_NC = 4
    night_tm_nonpit_buffer = 8

    #NIGHTS TLMD SORT ALLOCATION
    night_tm_TLMD_induct = 3
    night_tm_TLMD_picker = 4
    night_tm_TLMD_sort = 12

    #NIGHTS TLMD STAGE ALLOCATION
    night_tm_stage = 19
    night_tm_handoff = 19

    if night_tm_pit_unload + night_tm_pit_induct + night_tm_nonpit_split + night_tm_nonpit_NC + night_tm_nonpit_buffer > nights_total_tm:
        raise ValueError('Total number of TMs exceeds the limit')   
    
    if night_tm_TLMD_induct + night_tm_TLMD_picker + night_tm_TLMD_sort  >  nights_total_tm:
        raise ValueError('Total number of TMs exceeds the limit')

    if night_tm_stage > nights_total_tm or night_tm_handoff > nights_total_tm:
        raise ValueError('Total number of TMs exceeds the limit')
    
    unavailable_periods = [
        #(180, 210),  # Night shift bk1
        #(420, 435),  # Night shift bk2
        #(800, 810),  # Night shift shift gap
        #(990, 1020),  # Day shift break 1
        #(1230, 1245),  # Day shift break 2
        #(1410, 1440)  # Day shift shift gap
    ]

    # Setup inbound induct simulation
    env, sortation_center = setup_simulation(pallet_info, night_tm_pit_unload, night_tm_pit_induct, night_tm_nonpit_split, night_tm_nonpit_NC, night_tm_nonpit_buffer, unavailable_periods)

    # Run inbound induct simulation
    print("Begin Induct Process")
    env.run(until=800)
    print("End Induct Process")
   
    plot_metrics(sortation_center.metrics)
    print(len(G.TLMD_STAGED_PACKAGES))
    # Setup TLMD Sort simulation
    env, sortation_center = setup_simulation_2(G.TLMD_STAGED_PACKAGES, night_tm_TLMD_induct, night_tm_TLMD_picker, night_tm_TLMD_sort, unavailable_periods)
    if G.TLMD_INDUCT_TIME < 800:
        print('Begin TLMD Sort Process')
        env.run(until=(800-G.TLMD_INDUCT_TIME))
    print('End TLMD Sort Process')
    plot_metrics(sortation_center.metrics)

    #Determine if process is complete for the conduct of staging/handoff
    if len(G.PASSED_OVER_PALLETS_1)>0 or len(G.PASSED_OVER_PALLETS_2)>0 or len(G.PASSED_OVER_PALLETS_3)>0:
        print("Night Shift over before full sortation completed")
        print(f'Induct Line Run as Batch Process:')
        print("...................................")
        print(f'Induct process completed at {G.TLMD_INDUCT_TIME}')
        print(f'UPSN Packages staged for handoff at {G.UPSN_SORT_TIME}')
        print(f'USPS Packages staged for handoff at {G.USPS_SORT_TIME}')
        print(f'FDEG Packages staged for handoff at {G.FDEG_SORT_TIME}')
        print(f'FDE Packages staged for handoff at {G.FDE_SORT_TIME}')
        total_packages = 0
        total_packages_1 = 0
        total_packages_2= 0
        total_packages_3 = 0
        for pallet in G.TLMD_INDUCT_STAGING_PALLETS_CARRYOVER.items:
            total_packages += pallet.current_packages
        for package in G.TLMD_INDUCT_STAGING_PACKAGES_CARRYOVER.items:
            total_packages += 1
        for package in G.TLMD_SPLITTER_CARRYOVER.items:   
            total_packages += 1
        for package in G.TLMD_FINAL_SORT_CARRYOVER.items:
            total_packages += 1
        print(f'Total packages remaining as WIP: {total_packages}')
        if len(G.PASSED_OVER_PALLETS_1)>0:
            print(f'Remaining Partion 1 pallets: {len(G.PASSED_OVER_PALLETS_1)}')
            
            for pallet in G.PASSED_OVER_PALLETS_1:  # Assuming pallets_list is your list of TLMD_Pallet objects
                total_packages_1 += pallet.current_packages
            print(f'Partition 1 packages remaining: {total_packages_1+total_packages}')
        if len(G.PASSED_OVER_PALLETS_2)>0:
            print(f'Remaining Partion 2 pallets: {len(G.PASSED_OVER_PALLETS_2)}')
            
            for pallet in G.PASSED_OVER_PALLETS_2:  # Assuming pallets_list is your list of TLMD_Pallet objects
                total_packages_2 += pallet.current_packages
            if len(G.PASSED_OVER_PALLETS_1)==0:
                print(f'Partition 2 packages remaining: {total_packages_2+total_packages}')
            else:
                print(f'Partition 2 packages remaining: {total_packages_2}')
        if len(G.PASSED_OVER_PALLETS_3)>0:
            print(f'Remaining Partion 3 pallets: {len(G.PASSED_OVER_PALLETS_3)}')
            
            for pallet in G.PASSED_OVER_PALLETS_3:  # Assuming pallets_list is your list of TLMD_Pallet objects
                total_packages_3 += pallet.current_packages
            if len(G.PASSED_OVER_PALLETS_2)==0:
                print(f'Partition 3 packages remaining: {total_packages_3+total_packages}')
            else:
                print(f'Partition 3 packages remaining: {total_packages_3}')

        G.TOTAL_SHIFT_PACKAGE_CARRYOVER = total_packages_1+total_packages_2+total_packages_3+total_packages
        print(f'Total packages remaining at end of shift: {G.TOTAL_SHIFT_PACKAGE_CARRYOVER}')
                    
    else:
        #########################################
        # Setup TLMD Stage and Handoff simulation
        #########################################
        env, sortation_center = setup_simulation_3(night_tm_stage, night_tm_handoff, unavailable_periods)
        print('Begin TLMD Stage Process')
        env.run(until=800)
        print('End TLMD Stage Process')
        plot_metrics(sortation_center.metrics)
# Out:
# Total Inbound Packages: 7333
# Total Inbound TLMD Packages: 5158
# Total Inbound NC Packages: 2175
# Total Inbound UPSN Packages: 326
# Total Inbound USPS Packages: 762
# Total Inbound FDEG Packages: 1085
# Total Inbound FDE Packages: 2
# Begin Induct Process
# Pallet 1.0 arrived at 28.0
# Pallet 2.0 arrived at 29.0
# Pallet 3.0 arrived at 30.0
# Pallet 4.0 arrived at 31.0
# Pallet 5.0 arrived at 32.0
# Pallet 1.0 unloaded at 32.0
# Pallet 6.0 arrived at 33.0
# Pallet 2.0 unloaded at 33.0
# Pallet 7.0 arrived at 34.0
# Pallet 1.0 staged for induction at 34.72727272727273
# Package TLMD220049804891, TLMD inducted at 34.80227272727273
# Package TLMD220049803507, TLMD inducted at 34.80227272727273
# Package TLMD220049714630, TLMD inducted at 34.80227272727273
# Package TLMD220049804891 split to TLMD Buffer at 34.80227272727273
# Using tm_nonpit_buffer for sorting package TLMD220049804891 at 34.80227272727273
# Package TLMD220049803507 split to TLMD Buffer at 34.80227272727273
# Using tm_nonpit_buffer for sorting package TLMD220049803507 at 34.80227272727273
# Package TLMD220049714630 split to TLMD Buffer at 34.80227272727273
# Using tm_nonpit_buffer for sorting package TLMD220049714630 at 34.80227272727273
# Package 7.40E+11, FDEG inducted at 34.87727272727273
# Package TLMD220049905979, TLMD inducted at 34.87727272727273
# Package TLMD220049751644, TLMD inducted at 34.87727272727273
# Package 7.40E+11 split to National Sort at 34.87727272727273
# Package TLMD220049905979 split to TLMD Buffer at 34.87727272727273
# Using tm_nonpit_buffer for sorting package TLMD220049905979 at 34.87727272727273
# Package TLMD220049751644 split to TLMD Buffer at 34.87727272727273
# Using tm_nonpit_buffer for sorting package TLMD220049751644 at 34.87727272727273
# Package TLMD220049754007, TLMD inducted at 34.952272727272735
# Package TLMD220049753204, TLMD inducted at 34.952272727272735
# Package 7.40E+11, FDEG inducted at 34.952272727272735
# Package TLMD220049754007 split to TLMD Buffer at 34.952272727272735
# Using tm_nonpit_buffer for sorting package TLMD220049754007 at 34.952272727272735
# Package TLMD220049753204 split to TLMD Buffer at 34.952272727272735
# Using tm_nonpit_buffer for sorting package TLMD220049753204 at 34.952272727272735
# Package 7.40E+11 split to National Sort at 34.952272727272735
# Package TLMD220049713015, TLMD inducted at 35.02727272727274
# Package 7.40E+11, FDEG inducted at 35.02727272727274
# Package 7.40E+11, FDEG inducted at 35.02727272727274
# Package TLMD220049713015 split to TLMD Buffer at 35.02727272727274
# Using tm_nonpit_buffer for sorting package TLMD220049713015 at 35.02727272727274
# Package 7.40E+11 split to National Sort at 35.02727272727274
# Package 7.40E+11 split to National Sort at 35.02727272727274
# Package TLMD220049787017, TLMD inducted at 35.10227272727274
# Package TLMD220049905273, TLMD inducted at 35.10227272727274
# Package 7.40E+11, FDEG inducted at 35.10227272727274
# Package TLMD220049787017 split to TLMD Buffer at 35.10227272727274
# Package TLMD220049905273 split to TLMD Buffer at 35.10227272727274
# Package 7.40E+11 split to National Sort at 35.10227272727274
# Package TLMD220049711526, TLMD inducted at 35.177272727272744
# Package 7.40E+11, FDEG inducted at 35.177272727272744
# Package TLMD220049899236, TLMD inducted at 35.177272727272744
# Package TLMD220049711526 split to TLMD Buffer at 35.177272727272744
# Package 7.40E+11 split to National Sort at 35.177272727272744
# Package TLMD220049899236 split to TLMD Buffer at 35.177272727272744
# Package TLMD220049804891 sorted to TLMD Buffer using tm_nonpit_buffer at 35.20767813267813
# Package TLMD220049803507 sorted to TLMD Buffer using tm_nonpit_buffer at 35.20767813267813
# Package TLMD220049714630 sorted to TLMD Buffer using tm_nonpit_buffer at 35.20767813267813
# Using tm_nonpit_buffer for sorting package TLMD220049787017 at 35.20767813267813
# Using tm_nonpit_buffer for sorting package TLMD220049905273 at 35.20767813267813
# Using tm_nonpit_buffer for sorting package TLMD220049711526 at 35.20767813267813
# Package 9.26129E+21, USPS inducted at 35.25227272727275
# Package 7.40E+11, FDEG inducted at 35.25227272727275
# Package TLMD220049791217, TLMD inducted at 35.25227272727275
# Package 9.26129E+21 split to National Sort at 35.25227272727275
# Package 7.40E+11 split to National Sort at 35.25227272727275
# Package TLMD220049791217 split to TLMD Buffer at 35.25227272727275
# Package TLMD220049905979 sorted to TLMD Buffer using tm_nonpit_buffer at 35.282678132678136
# Package TLMD220049751644 sorted to TLMD Buffer using tm_nonpit_buffer at 35.282678132678136
# Using tm_nonpit_buffer for sorting package TLMD220049899236 at 35.282678132678136
# Using tm_nonpit_buffer for sorting package TLMD220049791217 at 35.282678132678136
# Package TLMD220049709280, TLMD inducted at 35.32727272727275
# Package TLMD220049711731, TLMD inducted at 35.32727272727275
# Package TLMD220049710358, TLMD inducted at 35.32727272727275
# Package TLMD220049709280 split to TLMD Buffer at 35.32727272727275
# Package TLMD220049711731 split to TLMD Buffer at 35.32727272727275
# Package TLMD220049710358 split to TLMD Buffer at 35.32727272727275
# Package TLMD220049754007 sorted to TLMD Buffer using tm_nonpit_buffer at 35.35767813267814
# Package TLMD220049753204 sorted to TLMD Buffer using tm_nonpit_buffer at 35.35767813267814
# Using tm_nonpit_buffer for sorting package TLMD220049709280 at 35.35767813267814
# Using tm_nonpit_buffer for sorting package TLMD220049711731 at 35.35767813267814
# Package TLMD220049751395, TLMD inducted at 35.40227272727275
# Package TLMD220049911186, TLMD inducted at 35.40227272727275
# Package TLMD220049790745, TLMD inducted at 35.40227272727275
# Package TLMD220049751395 split to TLMD Buffer at 35.40227272727275
# Package TLMD220049911186 split to TLMD Buffer at 35.40227272727275
# Package TLMD220049790745 split to TLMD Buffer at 35.40227272727275
# Package TLMD220049713015 sorted to TLMD Buffer using tm_nonpit_buffer at 35.43267813267814
# Using tm_nonpit_buffer for sorting package TLMD220049710358 at 35.43267813267814
# Package TLMD220049714952, TLMD inducted at 35.477272727272755
# Package TLMD220049896748, TLMD inducted at 35.477272727272755
# Package TLMD220049756247, TLMD inducted at 35.477272727272755
# Package TLMD220049714952 split to TLMD Buffer at 35.477272727272755
# Package TLMD220049896748 split to TLMD Buffer at 35.477272727272755
# Package TLMD220049756247 split to TLMD Buffer at 35.477272727272755
# Package TLMD220049900563, TLMD inducted at 35.55227272727276
# Package TLMD220049752045, TLMD inducted at 35.55227272727276
# Package TLMD220049901384, TLMD inducted at 35.55227272727276
# Package TLMD220049900563 split to TLMD Buffer at 35.55227272727276
# Package TLMD220049752045 split to TLMD Buffer at 35.55227272727276
# Package TLMD220049901384 split to TLMD Buffer at 35.55227272727276
# Package TLMD220049787017 sorted to TLMD Buffer using tm_nonpit_buffer at 35.613083538083536
# Package TLMD220049905273 sorted to TLMD Buffer using tm_nonpit_buffer at 35.613083538083536
# Package TLMD220049711526 sorted to TLMD Buffer using tm_nonpit_buffer at 35.613083538083536
# Using tm_nonpit_buffer for sorting package TLMD220049751395 at 35.613083538083536
# Using tm_nonpit_buffer for sorting package TLMD220049911186 at 35.613083538083536
# Using tm_nonpit_buffer for sorting package TLMD220049790745 at 35.613083538083536
# Package 7.40E+11, FDEG inducted at 35.62727272727276
# Package 7.40E+11, FDEG inducted at 35.62727272727276
# Package TLMD220049798345, TLMD inducted at 35.62727272727276
# Package 7.40E+11 split to National Sort at 35.62727272727276
# Package 7.40E+11 split to National Sort at 35.62727272727276
# Package TLMD220049798345 split to TLMD Buffer at 35.62727272727276
# Package TLMD220049899236 sorted to TLMD Buffer using tm_nonpit_buffer at 35.68808353808354
# Package TLMD220049791217 sorted to TLMD Buffer using tm_nonpit_buffer at 35.68808353808354
# Using tm_nonpit_buffer for sorting package TLMD220049714952 at 35.68808353808354
# Using tm_nonpit_buffer for sorting package TLMD220049896748 at 35.68808353808354
# Package TLMD220049709557, TLMD inducted at 35.702272727272764
# Package 7.40E+11, FDEG inducted at 35.702272727272764
# Package TLMD220049752876, TLMD inducted at 35.702272727272764
# Package TLMD220049709557 split to TLMD Buffer at 35.702272727272764
# Package 7.40E+11 split to National Sort at 35.702272727272764
# Package TLMD220049752876 split to TLMD Buffer at 35.702272727272764
# Pallet 2.0 staged for induction at 35.72727272727273
# Package TLMD220049709280 sorted to TLMD Buffer using tm_nonpit_buffer at 35.76308353808354
# Package TLMD220049711731 sorted to TLMD Buffer using tm_nonpit_buffer at 35.76308353808354
# Using tm_nonpit_buffer for sorting package TLMD220049756247 at 35.76308353808354
# Using tm_nonpit_buffer for sorting package TLMD220049900563 at 35.76308353808354
# Package TLMD220049907128, TLMD inducted at 35.777272727272766
# Package TLMD220049908967, TLMD inducted at 35.777272727272766
# Package TLMD220049705597, TLMD inducted at 35.777272727272766
# Package TLMD220049907128 split to TLMD Buffer at 35.777272727272766
# Package TLMD220049908967 split to TLMD Buffer at 35.777272727272766
# Package TLMD220049705597 split to TLMD Buffer at 35.777272727272766
# Package 7.40E+11, FDEG inducted at 35.80227272727273
# Package 7.40E+11 split to National Sort at 35.80227272727273
# Package TLMD220049710358 sorted to TLMD Buffer using tm_nonpit_buffer at 35.838083538083545
# Using tm_nonpit_buffer for sorting package TLMD220049752045 at 35.838083538083545
# Package TLMD220049752607, TLMD inducted at 35.85227272727277
# Package TLMD220049900956, TLMD inducted at 35.85227272727277
# Package TLMD220049752376, TLMD inducted at 35.85227272727277
# Package TLMD220049752607 split to TLMD Buffer at 35.85227272727277
# Package TLMD220049900956 split to TLMD Buffer at 35.85227272727277
# Package TLMD220049752376 split to TLMD Buffer at 35.85227272727277
# Package TLMD220049900269, TLMD inducted at 35.87727272727273
# Package TLMD220049900269 split to TLMD Buffer at 35.87727272727273
# Package TLMD220049796703, TLMD inducted at 35.92727272727277
# Package 7.40E+11, FDEG inducted at 35.92727272727277
# Package 1Z1A10F6YW41129789, UPSN inducted at 35.92727272727277
# Package TLMD220049796703 split to TLMD Buffer at 35.92727272727277
# Package 7.40E+11 split to National Sort at 35.92727272727277
# Package 1Z1A10F6YW41129789 split to National Sort at 35.92727272727277
# Package TLMD220049897256, TLMD inducted at 35.952272727272735
# Package TLMD220049897256 split to TLMD Buffer at 35.952272727272735
# Pallet 3.0 unloaded at 36.0
# Package 9.26129E+21, USPS inducted at 36.002272727272775
# Package TLMD220049705122, TLMD inducted at 36.002272727272775
# Package TLMD220049759422, TLMD inducted at 36.002272727272775
# Package 9.26129E+21 split to National Sort at 36.002272727272775
# Package TLMD220049705122 split to TLMD Buffer at 36.002272727272775
# Package TLMD220049759422 split to TLMD Buffer at 36.002272727272775
# Package TLMD220049751395 sorted to TLMD Buffer using tm_nonpit_buffer at 36.01848894348894
# Package TLMD220049911186 sorted to TLMD Buffer using tm_nonpit_buffer at 36.01848894348894
# Package TLMD220049790745 sorted to TLMD Buffer using tm_nonpit_buffer at 36.01848894348894
# Using tm_nonpit_buffer for sorting package TLMD220049901384 at 36.01848894348894
# Using tm_nonpit_buffer for sorting package TLMD220049798345 at 36.01848894348894
# Using tm_nonpit_buffer for sorting package TLMD220049709557 at 36.01848894348894
# Package TLMD220049795062, TLMD inducted at 36.02727272727274
# Package TLMD220049795062 split to TLMD Buffer at 36.02727272727274
# Package TLMD220049788196, TLMD inducted at 36.07727272727278
# Package 9.26129E+21, USPS inducted at 36.07727272727278
# Package TLMD220049789917, TLMD inducted at 36.07727272727278
# Package TLMD220049788196 split to TLMD Buffer at 36.07727272727278
# Package 9.26129E+21 split to National Sort at 36.07727272727278
# Package TLMD220049789917 split to TLMD Buffer at 36.07727272727278
# Package TLMD220049714952 sorted to TLMD Buffer using tm_nonpit_buffer at 36.09348894348894
# Package TLMD220049896748 sorted to TLMD Buffer using tm_nonpit_buffer at 36.09348894348894
# Using tm_nonpit_buffer for sorting package TLMD220049752876 at 36.09348894348894
# Using tm_nonpit_buffer for sorting package TLMD220049907128 at 36.09348894348894
# Package TLMD220049802606, TLMD inducted at 36.10227272727274
# Package TLMD220049802606 split to TLMD Buffer at 36.10227272727274
# Package TLMD220049805078, TLMD inducted at 36.15227272727278
# Package 1Z1A10F6YW41129805, UPSN inducted at 36.15227272727278
# Package 7.40E+11, FDEG inducted at 36.15227272727278
# Package TLMD220049805078 split to TLMD Buffer at 36.15227272727278
# Package 1Z1A10F6YW41129805 split to National Sort at 36.15227272727278
# Package 7.40E+11 split to National Sort at 36.15227272727278
# Package TLMD220049756247 sorted to TLMD Buffer using tm_nonpit_buffer at 36.168488943488946
# Package TLMD220049900563 sorted to TLMD Buffer using tm_nonpit_buffer at 36.168488943488946
# Using tm_nonpit_buffer for sorting package TLMD220049908967 at 36.168488943488946
# Using tm_nonpit_buffer for sorting package TLMD220049705597 at 36.168488943488946
# Package 9.26129E+21, USPS inducted at 36.177272727272744
# Package 9.26129E+21 split to National Sort at 36.177272727272744
# Package TLMD220049788696, TLMD inducted at 36.22727272727278
# Package TLMD220049787704, TLMD inducted at 36.22727272727278
# Package TLMD220049758503, TLMD inducted at 36.22727272727278
# Package TLMD220049788696 split to TLMD Buffer at 36.22727272727278
# Package TLMD220049787704 split to TLMD Buffer at 36.22727272727278
# Package TLMD220049758503 split to TLMD Buffer at 36.22727272727278
# Package TLMD220049752045 sorted to TLMD Buffer using tm_nonpit_buffer at 36.24348894348895
# Using tm_nonpit_buffer for sorting package TLMD220049752607 at 36.24348894348895
# Package TLMD220049757951, TLMD inducted at 36.25227272727275
# Package TLMD220049757951 split to TLMD Buffer at 36.25227272727275
# Package 7.40E+11, FDEG inducted at 36.302272727272786
# Package TLMD220049902016, TLMD inducted at 36.302272727272786
# Package TLMD220049899843, TLMD inducted at 36.302272727272786
# Package 7.40E+11 split to National Sort at 36.302272727272786
# Package TLMD220049902016 split to TLMD Buffer at 36.302272727272786
# Package TLMD220049899843 split to TLMD Buffer at 36.302272727272786
# Package TLMD220049758870, TLMD inducted at 36.32727272727275
# Package TLMD220049758870 split to TLMD Buffer at 36.32727272727275
# Package TLMD220049712785, TLMD inducted at 36.37727272727279
# Package 9.26129E+21, USPS inducted at 36.37727272727279
# Package 9.26129E+21, USPS inducted at 36.37727272727279
# Package TLMD220049712785 split to TLMD Buffer at 36.37727272727279
# Package 9.26129E+21 split to National Sort at 36.37727272727279
# Package 9.26129E+21 split to National Sort at 36.37727272727279
# Package 7.40E+11, FDEG inducted at 36.40227272727275
# Package 7.40E+11 split to National Sort at 36.40227272727275
# Package TLMD220049901384 sorted to TLMD Buffer using tm_nonpit_buffer at 36.42389434889434
# Package TLMD220049798345 sorted to TLMD Buffer using tm_nonpit_buffer at 36.42389434889434
# Package TLMD220049709557 sorted to TLMD Buffer using tm_nonpit_buffer at 36.42389434889434
# Using tm_nonpit_buffer for sorting package TLMD220049900956 at 36.42389434889434
# Using tm_nonpit_buffer for sorting package TLMD220049752376 at 36.42389434889434
# Using tm_nonpit_buffer for sorting package TLMD220049900269 at 36.42389434889434
# Package TLMD220049750725, TLMD inducted at 36.45227272727279
# Package 1Z1A10F6YW41129798, UPSN inducted at 36.45227272727279
# Package TLMD220049756676, TLMD inducted at 36.45227272727279
# Package TLMD220049750725 split to TLMD Buffer at 36.45227272727279
# Package 1Z1A10F6YW41129798 split to National Sort at 36.45227272727279
# Package TLMD220049756676 split to TLMD Buffer at 36.45227272727279
# Package TLMD220049791637, TLMD inducted at 36.477272727272755
# Package TLMD220049791637 split to TLMD Buffer at 36.477272727272755
# Package TLMD220049752876 sorted to TLMD Buffer using tm_nonpit_buffer at 36.498894348894346
# Package TLMD220049907128 sorted to TLMD Buffer using tm_nonpit_buffer at 36.498894348894346
# Using tm_nonpit_buffer for sorting package TLMD220049796703 at 36.498894348894346
# Using tm_nonpit_buffer for sorting package TLMD220049897256 at 36.498894348894346
# Package 7.40E+11, FDEG inducted at 36.527272727272795
# Package TLMD220049753464, TLMD inducted at 36.527272727272795
# Package TLMD220049789266, TLMD inducted at 36.527272727272795
# Package 7.40E+11 split to National Sort at 36.527272727272795
# Package TLMD220049753464 split to TLMD Buffer at 36.527272727272795
# Package TLMD220049789266 split to TLMD Buffer at 36.527272727272795
# Package 7.40E+11, FDEG inducted at 36.55227272727276
# Package 7.40E+11 split to National Sort at 36.55227272727276
# Package TLMD220049908967 sorted to TLMD Buffer using tm_nonpit_buffer at 36.57389434889435
# Package TLMD220049705597 sorted to TLMD Buffer using tm_nonpit_buffer at 36.57389434889435
# Using tm_nonpit_buffer for sorting package TLMD220049705122 at 36.57389434889435
# Using tm_nonpit_buffer for sorting package TLMD220049759422 at 36.57389434889435
# Package TLMD220049910570, TLMD inducted at 36.6022727272728
# Package TLMD220049804248, TLMD inducted at 36.6022727272728
# Package TLMD220049795991, TLMD inducted at 36.6022727272728
# Package TLMD220049910570 split to TLMD Buffer at 36.6022727272728
# Package TLMD220049804248 split to TLMD Buffer at 36.6022727272728
# Package TLMD220049795991 split to TLMD Buffer at 36.6022727272728
# Package TLMD220049706541, TLMD inducted at 36.62727272727276
# Pallet 1.0 removed from queue_induct_staging_pallets at 36.62727272727276
# Package TLMD220049706541 split to TLMD Buffer at 36.62727272727276
# Package TLMD220049752607 sorted to TLMD Buffer using tm_nonpit_buffer at 36.64889434889435
# Using tm_nonpit_buffer for sorting package TLMD220049795062 at 36.64889434889435
# Package TLMD220049703473, TLMD inducted at 36.6772727272728
# Package TLMD220049692468, TLMD inducted at 36.6772727272728
# Package TLMD220049695214, TLMD inducted at 36.6772727272728
# Package TLMD220049703473 split to TLMD Buffer at 36.6772727272728
# Package TLMD220049692468 split to TLMD Buffer at 36.6772727272728
# Package TLMD220049695214 split to TLMD Buffer at 36.6772727272728
# Package TLMD220049691174, TLMD inducted at 36.702272727272764
# Package TLMD220049691174 split to TLMD Buffer at 36.702272727272764
# Package 7.40E+11, FDEG inducted at 36.7522727272728
# Package 7.40E+11, FDEG inducted at 36.7522727272728
# Package TLMD220049691629, TLMD inducted at 36.7522727272728
# Package 7.40E+11 split to National Sort at 36.7522727272728
# Package 7.40E+11 split to National Sort at 36.7522727272728
# Package TLMD220049691629 split to TLMD Buffer at 36.7522727272728
# Package 1Z1A10F60341129778, UPSN inducted at 36.777272727272766
# Package 1Z1A10F60341129778 split to National Sort at 36.777272727272766
# Package TLMD220049693887, TLMD inducted at 36.827272727272806
# Package TLMD220049695027, TLMD inducted at 36.827272727272806
# Package TLMD220049703151, TLMD inducted at 36.827272727272806
# Package TLMD220049693887 split to TLMD Buffer at 36.827272727272806
# Package TLMD220049695027 split to TLMD Buffer at 36.827272727272806
# Package TLMD220049703151 split to TLMD Buffer at 36.827272727272806
# Package TLMD220049900956 sorted to TLMD Buffer using tm_nonpit_buffer at 36.82929975429975
# Package TLMD220049752376 sorted to TLMD Buffer using tm_nonpit_buffer at 36.82929975429975
# Package TLMD220049900269 sorted to TLMD Buffer using tm_nonpit_buffer at 36.82929975429975
# Using tm_nonpit_buffer for sorting package TLMD220049788196 at 36.82929975429975
# Using tm_nonpit_buffer for sorting package TLMD220049789917 at 36.82929975429975
# Using tm_nonpit_buffer for sorting package TLMD220049802606 at 36.82929975429975
# Package TLMD220049701108, TLMD inducted at 36.85227272727277
# Package TLMD220049701108 split to TLMD Buffer at 36.85227272727277
# Package TLMD220049691352, TLMD inducted at 36.90227272727281
# Package TLMD220049701626, TLMD inducted at 36.90227272727281
# Package TLMD220049703848, TLMD inducted at 36.90227272727281
# Package TLMD220049691352 split to TLMD Buffer at 36.90227272727281
# Package TLMD220049701626 split to TLMD Buffer at 36.90227272727281
# Package TLMD220049703848 split to TLMD Buffer at 36.90227272727281
# Package TLMD220049796703 sorted to TLMD Buffer using tm_nonpit_buffer at 36.90429975429975
# Package TLMD220049897256 sorted to TLMD Buffer using tm_nonpit_buffer at 36.90429975429975
# Using tm_nonpit_buffer for sorting package TLMD220049805078 at 36.90429975429975
# Using tm_nonpit_buffer for sorting package TLMD220049788696 at 36.90429975429975
# Package TLMD220049702054, TLMD inducted at 36.92727272727277
# Package TLMD220049702054 split to TLMD Buffer at 36.92727272727277
# Package TLMD220049694868, TLMD inducted at 36.97727272727281
# Package TLMD220049691905, TLMD inducted at 36.97727272727281
# Package TLMD220049692753, TLMD inducted at 36.97727272727281
# Package TLMD220049694868 split to TLMD Buffer at 36.97727272727281
# Package TLMD220049691905 split to TLMD Buffer at 36.97727272727281
# Package TLMD220049692753 split to TLMD Buffer at 36.97727272727281
# Package TLMD220049705122 sorted to TLMD Buffer using tm_nonpit_buffer at 36.97929975429975
# Package TLMD220049759422 sorted to TLMD Buffer using tm_nonpit_buffer at 36.97929975429975
# Using tm_nonpit_buffer for sorting package TLMD220049787704 at 36.97929975429975
# Using tm_nonpit_buffer for sorting package TLMD220049758503 at 36.97929975429975
# Pallet 4.0 unloaded at 37.0
# Package TLMD220049693529, TLMD inducted at 37.002272727272775
# Package TLMD220049693529 split to TLMD Buffer at 37.002272727272775
# Package TLMD220049693396, TLMD inducted at 37.052272727272815
# Package TLMD220049691772, TLMD inducted at 37.052272727272815
# Package TLMD220049703786, TLMD inducted at 37.052272727272815
# Package TLMD220049693396 split to TLMD Buffer at 37.052272727272815
# Package TLMD220049691772 split to TLMD Buffer at 37.052272727272815
# Package TLMD220049703786 split to TLMD Buffer at 37.052272727272815
# Package TLMD220049795062 sorted to TLMD Buffer using tm_nonpit_buffer at 37.054299754299755
# Using tm_nonpit_buffer for sorting package TLMD220049757951 at 37.054299754299755
# Package 1Z1A10F60341129769, UPSN inducted at 37.07727272727278
# Package 1Z1A10F60341129769 split to National Sort at 37.07727272727278
# Package TLMD220049696213, TLMD inducted at 37.12727272727282
# Package TLMD220049702312, TLMD inducted at 37.12727272727282
# Package TLMD220049694966, TLMD inducted at 37.12727272727282
# Package TLMD220049696213 split to TLMD Buffer at 37.12727272727282
# Package TLMD220049702312 split to TLMD Buffer at 37.12727272727282
# Pallet 2.0 removed from queue_induct_staging_pallets at 37.12727272727282
# Package TLMD220049694966 split to TLMD Buffer at 37.12727272727282
# Package TLMD220049788196 sorted to TLMD Buffer using tm_nonpit_buffer at 37.23470515970515
# Package TLMD220049789917 sorted to TLMD Buffer using tm_nonpit_buffer at 37.23470515970515
# Package TLMD220049802606 sorted to TLMD Buffer using tm_nonpit_buffer at 37.23470515970515
# Using tm_nonpit_buffer for sorting package TLMD220049902016 at 37.23470515970515
# Using tm_nonpit_buffer for sorting package TLMD220049899843 at 37.23470515970515
# Using tm_nonpit_buffer for sorting package TLMD220049758870 at 37.23470515970515
# Package TLMD220049805078 sorted to TLMD Buffer using tm_nonpit_buffer at 37.30970515970515
# Package TLMD220049788696 sorted to TLMD Buffer using tm_nonpit_buffer at 37.30970515970515
# Using tm_nonpit_buffer for sorting package TLMD220049712785 at 37.30970515970515
# Using tm_nonpit_buffer for sorting package TLMD220049750725 at 37.30970515970515
# Package TLMD220049787704 sorted to TLMD Buffer using tm_nonpit_buffer at 37.384705159705156
# Package TLMD220049758503 sorted to TLMD Buffer using tm_nonpit_buffer at 37.384705159705156
# Using tm_nonpit_buffer for sorting package TLMD220049756676 at 37.384705159705156
# Using tm_nonpit_buffer for sorting package TLMD220049791637 at 37.384705159705156
# Package TLMD220049757951 sorted to TLMD Buffer using tm_nonpit_buffer at 37.45970515970516
# Using tm_nonpit_buffer for sorting package TLMD220049753464 at 37.45970515970516
# Package TLMD220049902016 sorted to TLMD Buffer using tm_nonpit_buffer at 37.640110565110554
# Package TLMD220049899843 sorted to TLMD Buffer using tm_nonpit_buffer at 37.640110565110554
# Package TLMD220049758870 sorted to TLMD Buffer using tm_nonpit_buffer at 37.640110565110554
# Using tm_nonpit_buffer for sorting package TLMD220049789266 at 37.640110565110554
# Using tm_nonpit_buffer for sorting package TLMD220049910570 at 37.640110565110554
# Using tm_nonpit_buffer for sorting package TLMD220049804248 at 37.640110565110554
# Package TLMD220049712785 sorted to TLMD Buffer using tm_nonpit_buffer at 37.71511056511056
# Package TLMD220049750725 sorted to TLMD Buffer using tm_nonpit_buffer at 37.71511056511056
# Using tm_nonpit_buffer for sorting package TLMD220049795991 at 37.71511056511056
# Using tm_nonpit_buffer for sorting package TLMD220049706541 at 37.71511056511056
# Package TLMD220049756676 sorted to TLMD Buffer using tm_nonpit_buffer at 37.79011056511056
# Package TLMD220049791637 sorted to TLMD Buffer using tm_nonpit_buffer at 37.79011056511056
# Using tm_nonpit_buffer for sorting package TLMD220049703473 at 37.79011056511056
# Using tm_nonpit_buffer for sorting package TLMD220049692468 at 37.79011056511056
# Package TLMD220049753464 sorted to TLMD Buffer using tm_nonpit_buffer at 37.86511056511056
# Using tm_nonpit_buffer for sorting package TLMD220049695214 at 37.86511056511056
# Package TLMD220049789266 sorted to TLMD Buffer using tm_nonpit_buffer at 38.04551597051596
# Package TLMD220049910570 sorted to TLMD Buffer using tm_nonpit_buffer at 38.04551597051596
# Package TLMD220049804248 sorted to TLMD Buffer using tm_nonpit_buffer at 38.04551597051596
# Using tm_nonpit_buffer for sorting package TLMD220049691174 at 38.04551597051596
# Using tm_nonpit_buffer for sorting package TLMD220049691629 at 38.04551597051596
# Using tm_nonpit_buffer for sorting package TLMD220049693887 at 38.04551597051596
# Package TLMD220049795991 sorted to TLMD Buffer using tm_nonpit_buffer at 38.12051597051596
# Package TLMD220049706541 sorted to TLMD Buffer using tm_nonpit_buffer at 38.12051597051596
# Using tm_nonpit_buffer for sorting package TLMD220049695027 at 38.12051597051596
# Using tm_nonpit_buffer for sorting package TLMD220049703151 at 38.12051597051596
# Package TLMD220049703473 sorted to TLMD Buffer using tm_nonpit_buffer at 38.19551597051596
# Package TLMD220049692468 sorted to TLMD Buffer using tm_nonpit_buffer at 38.19551597051596
# Using tm_nonpit_buffer for sorting package TLMD220049701108 at 38.19551597051596
# Using tm_nonpit_buffer for sorting package TLMD220049691352 at 38.19551597051596
# Package TLMD220049695214 sorted to TLMD Buffer using tm_nonpit_buffer at 38.270515970515966
# Using tm_nonpit_buffer for sorting package TLMD220049701626 at 38.270515970515966
# Package TLMD220049691174 sorted to TLMD Buffer using tm_nonpit_buffer at 38.45092137592136
# Package TLMD220049691629 sorted to TLMD Buffer using tm_nonpit_buffer at 38.45092137592136
# Package TLMD220049693887 sorted to TLMD Buffer using tm_nonpit_buffer at 38.45092137592136
# Using tm_nonpit_buffer for sorting package TLMD220049703848 at 38.45092137592136
# Using tm_nonpit_buffer for sorting package TLMD220049702054 at 38.45092137592136
# Using tm_nonpit_buffer for sorting package TLMD220049694868 at 38.45092137592136
# Package TLMD220049695027 sorted to TLMD Buffer using tm_nonpit_buffer at 38.525921375921364
# Package TLMD220049703151 sorted to TLMD Buffer using tm_nonpit_buffer at 38.525921375921364
# Using tm_nonpit_buffer for sorting package TLMD220049691905 at 38.525921375921364
# Using tm_nonpit_buffer for sorting package TLMD220049692753 at 38.525921375921364
# Package TLMD220049701108 sorted to TLMD Buffer using tm_nonpit_buffer at 38.60092137592137
# Package TLMD220049691352 sorted to TLMD Buffer using tm_nonpit_buffer at 38.60092137592137
# Using tm_nonpit_buffer for sorting package TLMD220049693529 at 38.60092137592137
# Using tm_nonpit_buffer for sorting package TLMD220049693396 at 38.60092137592137
# Package TLMD220049701626 sorted to TLMD Buffer using tm_nonpit_buffer at 38.67592137592137
# Using tm_nonpit_buffer for sorting package TLMD220049691772 at 38.67592137592137
# Package TLMD220049703848 sorted to TLMD Buffer using tm_nonpit_buffer at 38.856326781326764
# Package TLMD220049702054 sorted to TLMD Buffer using tm_nonpit_buffer at 38.856326781326764
# Package TLMD220049694868 sorted to TLMD Buffer using tm_nonpit_buffer at 38.856326781326764
# Using tm_nonpit_buffer for sorting package TLMD220049703786 at 38.856326781326764
# Using tm_nonpit_buffer for sorting package TLMD220049696213 at 38.856326781326764
# Using tm_nonpit_buffer for sorting package TLMD220049702312 at 38.856326781326764
# Package TLMD220049691905 sorted to TLMD Buffer using tm_nonpit_buffer at 38.93132678132677
# Package TLMD220049692753 sorted to TLMD Buffer using tm_nonpit_buffer at 38.93132678132677
# Using tm_nonpit_buffer for sorting package TLMD220049694966 at 38.93132678132677
# Package TLMD220049693529 sorted to TLMD Buffer using tm_nonpit_buffer at 39.00632678132677
# Package TLMD220049693396 sorted to TLMD Buffer using tm_nonpit_buffer at 39.00632678132677
# Package TLMD220049691772 sorted to TLMD Buffer using tm_nonpit_buffer at 39.08132678132677
# Package TLMD220049703786 sorted to TLMD Buffer using tm_nonpit_buffer at 39.26173218673217
# Package TLMD220049696213 sorted to TLMD Buffer using tm_nonpit_buffer at 39.26173218673217
# Package TLMD220049702312 sorted to TLMD Buffer using tm_nonpit_buffer at 39.26173218673217
# Package TLMD220049694966 sorted to TLMD Buffer using tm_nonpit_buffer at 39.33673218673217
# Pallet 3.0 staged for induction at 39.804545454545504
# Pallet 4.0 staged for induction at 39.854545454545544
# Package TLMD183249915977, TLMD inducted at 39.87954545454551
# Package TLMD183249915422, TLMD inducted at 39.87954545454551
# Package TLMD183249917911, TLMD inducted at 39.87954545454551
# Package TLMD183249915977 split to TLMD Buffer at 39.87954545454551
# Using tm_nonpit_buffer for sorting package TLMD183249915977 at 39.87954545454551
# Package TLMD183249915422 split to TLMD Buffer at 39.87954545454551
# Using tm_nonpit_buffer for sorting package TLMD183249915422 at 39.87954545454551
# Package TLMD183249917911 split to TLMD Buffer at 39.87954545454551
# Using tm_nonpit_buffer for sorting package TLMD183249917911 at 39.87954545454551
# Package 7.40E+11, FDEG inducted at 39.92954545454555
# Package 7.40E+11 split to National Sort at 39.92954545454555
# Package TLMD183249898040, TLMD inducted at 39.95454545454551
# Package TLMD183249895892, TLMD inducted at 39.95454545454551
# Package 7.40E+11, FDEG inducted at 39.95454545454551
# Package TLMD183249898040 split to TLMD Buffer at 39.95454545454551
# Using tm_nonpit_buffer for sorting package TLMD183249898040 at 39.95454545454551
# Package TLMD183249895892 split to TLMD Buffer at 39.95454545454551
# Using tm_nonpit_buffer for sorting package TLMD183249895892 at 39.95454545454551
# Package 7.40E+11 split to National Sort at 39.95454545454551
# Pallet 5.0 unloaded at 40.0
# Package 7.40E+11, FDEG inducted at 40.00454545454555
# Package 7.40E+11 split to National Sort at 40.00454545454555
# Package TLMD183249916949, TLMD inducted at 40.02954545454551
# Package 7.40E+11, FDEG inducted at 40.02954545454551
# Package 7.40E+11, FDEG inducted at 40.02954545454551
# Package TLMD183249916949 split to TLMD Buffer at 40.02954545454551
# Using tm_nonpit_buffer for sorting package TLMD183249916949 at 40.02954545454551
# Package 7.40E+11 split to National Sort at 40.02954545454551
# Package 7.40E+11 split to National Sort at 40.02954545454551
# Package TLMD183249904694, TLMD inducted at 40.07954545454555
# Package TLMD183249904694 split to TLMD Buffer at 40.07954545454555
# Using tm_nonpit_buffer for sorting package TLMD183249904694 at 40.07954545454555
# Package 7.40E+11, FDEG inducted at 40.104545454545516
# Package TLMD183249917126, TLMD inducted at 40.104545454545516
# Package TLMD183249896104, TLMD inducted at 40.104545454545516
# Package 7.40E+11 split to National Sort at 40.104545454545516
# Package TLMD183249917126 split to TLMD Buffer at 40.104545454545516
# Using tm_nonpit_buffer for sorting package TLMD183249917126 at 40.104545454545516
# Package TLMD183249896104 split to TLMD Buffer at 40.104545454545516
# Package 7.40E+11, FDEG inducted at 40.154545454545556
# Package 7.40E+11 split to National Sort at 40.154545454545556
# Package TLMD183249913737, TLMD inducted at 40.17954545454552
# Package TLMD183249903711, TLMD inducted at 40.17954545454552
# Package 1Z300FX3YW43259990, UPSN inducted at 40.17954545454552
# Package TLMD183249913737 split to TLMD Buffer at 40.17954545454552
# Pallet 3.0 removed from queue_induct_staging_pallets at 40.17954545454552
# Package TLMD183249903711 split to TLMD Buffer at 40.17954545454552
# Package 1Z300FX3YW43259990 split to National Sort at 40.17954545454552
# Package TLMD183249907379, TLMD inducted at 40.22954545454556
# Package TLMD183249907379 split to TLMD Buffer at 40.22954545454556
# Package TLMD183249899772, TLMD inducted at 40.25454545454552
# Package TLMD61949770847, TLMD inducted at 40.25454545454552
# Package 9.26129E+21, USPS inducted at 40.25454545454552
# Package TLMD183249899772 split to TLMD Buffer at 40.25454545454552
# Package TLMD61949770847 split to TLMD Buffer at 40.25454545454552
# Package 9.26129E+21 split to National Sort at 40.25454545454552
# Package TLMD183249915977 sorted to TLMD Buffer using tm_nonpit_buffer at 40.28495085995091
# Package TLMD183249915422 sorted to TLMD Buffer using tm_nonpit_buffer at 40.28495085995091
# Package TLMD183249917911 sorted to TLMD Buffer using tm_nonpit_buffer at 40.28495085995091
# Using tm_nonpit_buffer for sorting package TLMD183249896104 at 40.28495085995091
# Using tm_nonpit_buffer for sorting package TLMD183249913737 at 40.28495085995091
# Using tm_nonpit_buffer for sorting package TLMD183249903711 at 40.28495085995091
# Package 7.40E+11, FDEG inducted at 40.30454545454556
# Package 7.40E+11 split to National Sort at 40.30454545454556
# Package 7.40E+11, FDEG inducted at 40.329545454545524
# Package TLMD183249903364, TLMD inducted at 40.329545454545524
# Package 9.26129E+21, USPS inducted at 40.329545454545524
# Package 7.40E+11 split to National Sort at 40.329545454545524
# Package TLMD183249903364 split to TLMD Buffer at 40.329545454545524
# Package 9.26129E+21 split to National Sort at 40.329545454545524
# Package TLMD183249898040 sorted to TLMD Buffer using tm_nonpit_buffer at 40.359950859950914
# Package TLMD183249895892 sorted to TLMD Buffer using tm_nonpit_buffer at 40.359950859950914
# Using tm_nonpit_buffer for sorting package TLMD183249907379 at 40.359950859950914
# Using tm_nonpit_buffer for sorting package TLMD183249899772 at 40.359950859950914
# Package 7.40E+11, FDEG inducted at 40.379545454545564
# Package 7.40E+11 split to National Sort at 40.379545454545564
# Package 9.26129E+21, USPS inducted at 40.40454545454553
# Package 7.40E+11, FDEG inducted at 40.40454545454553
# Package 7.40E+11, FDEG inducted at 40.40454545454553
# Package 9.26129E+21 split to National Sort at 40.40454545454553
# Package 7.40E+11 split to National Sort at 40.40454545454553
# Package 7.40E+11 split to National Sort at 40.40454545454553
# Package TLMD183249916949 sorted to TLMD Buffer using tm_nonpit_buffer at 40.434950859950916
# Using tm_nonpit_buffer for sorting package TLMD61949770847 at 40.434950859950916
# Package TLMD183249913059, TLMD inducted at 40.45454545454557
# Package TLMD183249913059 split to TLMD Buffer at 40.45454545454557
# Package TLMD183249914110, TLMD inducted at 40.47954545454553
# Package TLMD183249896560, TLMD inducted at 40.47954545454553
# Package 7.40E+11, FDEG inducted at 40.47954545454553
# Package TLMD183249914110 split to TLMD Buffer at 40.47954545454553
# Package TLMD183249896560 split to TLMD Buffer at 40.47954545454553
# Package 7.40E+11 split to National Sort at 40.47954545454553
# Package TLMD183249904694 sorted to TLMD Buffer using tm_nonpit_buffer at 40.484950859950956
# Using tm_nonpit_buffer for sorting package TLMD183249903364 at 40.484950859950956
# Package TLMD183249917126 sorted to TLMD Buffer using tm_nonpit_buffer at 40.50995085995092
# Using tm_nonpit_buffer for sorting package TLMD183249913059 at 40.50995085995092
# Package TLMD183249756596, TLMD inducted at 40.52954545454557
# Package TLMD183249756596 split to TLMD Buffer at 40.52954545454557
# Package TLMD183249897970, TLMD inducted at 40.55454545454553
# Package TLMD183249917984, TLMD inducted at 40.55454545454553
# Package TLMD183249918447, TLMD inducted at 40.55454545454553
# Package TLMD183249897970 split to TLMD Buffer at 40.55454545454553
# Package TLMD183249917984 split to TLMD Buffer at 40.55454545454553
# Package TLMD183249918447 split to TLMD Buffer at 40.55454545454553
# Package TLMD183249916458, TLMD inducted at 40.60454545454557
# Package TLMD183249916458 split to TLMD Buffer at 40.60454545454557
# Package TLMD183249900938, TLMD inducted at 40.629545454545536
# Package TLMD183249914487, TLMD inducted at 40.629545454545536
# Package 7.40E+11, FDEG inducted at 40.629545454545536
# Package TLMD183249900938 split to TLMD Buffer at 40.629545454545536
# Package TLMD183249914487 split to TLMD Buffer at 40.629545454545536
# Package 7.40E+11 split to National Sort at 40.629545454545536
# Package 7.40E+11, FDEG inducted at 40.679545454545575
# Package 7.40E+11 split to National Sort at 40.679545454545575
# Package TLMD183249896104 sorted to TLMD Buffer using tm_nonpit_buffer at 40.690356265356314
# Package TLMD183249913737 sorted to TLMD Buffer using tm_nonpit_buffer at 40.690356265356314
# Package TLMD183249903711 sorted to TLMD Buffer using tm_nonpit_buffer at 40.690356265356314
# Using tm_nonpit_buffer for sorting package TLMD183249914110 at 40.690356265356314
# Using tm_nonpit_buffer for sorting package TLMD183249896560 at 40.690356265356314
# Using tm_nonpit_buffer for sorting package TLMD183249756596 at 40.690356265356314
# Package 7.40E+11, FDEG inducted at 40.70454545454554
# Package TLMD61949693574, TLMD inducted at 40.70454545454554
# Package 9.26129E+21, USPS inducted at 40.70454545454554
# Package 7.40E+11 split to National Sort at 40.70454545454554
# Package TLMD61949693574 split to TLMD Buffer at 40.70454545454554
# Package 9.26129E+21 split to National Sort at 40.70454545454554
# Package TLMD183249898362, TLMD inducted at 40.75454545454558
# Package TLMD183249898362 split to TLMD Buffer at 40.75454545454558
# Package TLMD183249907379 sorted to TLMD Buffer using tm_nonpit_buffer at 40.76535626535632
# Package TLMD183249899772 sorted to TLMD Buffer using tm_nonpit_buffer at 40.76535626535632
# Using tm_nonpit_buffer for sorting package TLMD183249897970 at 40.76535626535632
# Using tm_nonpit_buffer for sorting package TLMD183249917984 at 40.76535626535632
# Package TLMD61949711026, TLMD inducted at 40.77954545454554
# Package TLMD183249733879, TLMD inducted at 40.77954545454554
# Package 9.26129E+21, USPS inducted at 40.77954545454554
# Package TLMD61949711026 split to TLMD Buffer at 40.77954545454554
# Package TLMD183249733879 split to TLMD Buffer at 40.77954545454554
# Package 9.26129E+21 split to National Sort at 40.77954545454554
# Package TLMD183249904747, TLMD inducted at 40.82954545454558
# Package TLMD183249904747 split to TLMD Buffer at 40.82954545454558
# Package TLMD61949770847 sorted to TLMD Buffer using tm_nonpit_buffer at 40.84035626535632
# Using tm_nonpit_buffer for sorting package TLMD183249918447 at 40.84035626535632
# Package TLMD183249893161, TLMD inducted at 40.854545454545544
# Package TLMD183249899987, TLMD inducted at 40.854545454545544
# Package TLMD183249893812, TLMD inducted at 40.854545454545544
# Package TLMD183249893161 split to TLMD Buffer at 40.854545454545544
# Package TLMD183249899987 split to TLMD Buffer at 40.854545454545544
# Package TLMD183249893812 split to TLMD Buffer at 40.854545454545544
# Package TLMD183249903364 sorted to TLMD Buffer using tm_nonpit_buffer at 40.89035626535636
# Using tm_nonpit_buffer for sorting package TLMD183249916458 at 40.89035626535636
# Package 9.26129E+21, USPS inducted at 40.904545454545584
# Package 9.26129E+21 split to National Sort at 40.904545454545584
# Package TLMD183249913059 sorted to TLMD Buffer using tm_nonpit_buffer at 40.91535626535632
# Using tm_nonpit_buffer for sorting package TLMD183249900938 at 40.91535626535632
# Package TLMD183249907182, TLMD inducted at 40.92954545454555
# Package 7.40E+11, FDEG inducted at 40.92954545454555
# Package 7.40E+11, FDEG inducted at 40.92954545454555
# Package TLMD183249907182 split to TLMD Buffer at 40.92954545454555
# Package 7.40E+11 split to National Sort at 40.92954545454555
# Package 7.40E+11 split to National Sort at 40.92954545454555
# Package TLMD61949678260, TLMD inducted at 40.97954545454559
# Package TLMD61949678260 split to TLMD Buffer at 40.97954545454559
# Pallet 6.0 unloaded at 41.0
# Package TLMD183249903266, TLMD inducted at 41.00454545454555
# Package TLMD183249765684, TLMD inducted at 41.00454545454555
# Package TLMD183249906192, TLMD inducted at 41.00454545454555
# Package TLMD183249903266 split to TLMD Buffer at 41.00454545454555
# Package TLMD183249765684 split to TLMD Buffer at 41.00454545454555
# Package TLMD183249906192 split to TLMD Buffer at 41.00454545454555
# Package 7.40E+11, FDEG inducted at 41.05454545454559
# Package 7.40E+11 split to National Sort at 41.05454545454559
# Package TLMD183249905915, TLMD inducted at 41.07954545454555
# Package TLMD61949676271, TLMD inducted at 41.07954545454555
# Package TLMD61949770534, TLMD inducted at 41.07954545454555
# Package TLMD183249905915 split to TLMD Buffer at 41.07954545454555
# Package TLMD61949676271 split to TLMD Buffer at 41.07954545454555
# Package TLMD61949770534 split to TLMD Buffer at 41.07954545454555
# Package TLMD183249914110 sorted to TLMD Buffer using tm_nonpit_buffer at 41.09576167076172
# Package TLMD183249896560 sorted to TLMD Buffer using tm_nonpit_buffer at 41.09576167076172
# Package TLMD183249756596 sorted to TLMD Buffer using tm_nonpit_buffer at 41.09576167076172
# Using tm_nonpit_buffer for sorting package TLMD183249914487 at 41.09576167076172
# Using tm_nonpit_buffer for sorting package TLMD61949693574 at 41.09576167076172
# Using tm_nonpit_buffer for sorting package TLMD183249898362 at 41.09576167076172
# Package 7.40E+11, FDEG inducted at 41.12954545454559
# Package 7.40E+11 split to National Sort at 41.12954545454559
# Package TLMD183249912514, TLMD inducted at 41.154545454545556
# Package TLMD61949737562, TLMD inducted at 41.154545454545556
# Package TLMD183249906638, TLMD inducted at 41.154545454545556
# Package TLMD183249912514 split to TLMD Buffer at 41.154545454545556
# Package TLMD61949737562 split to TLMD Buffer at 41.154545454545556
# Package TLMD183249906638 split to TLMD Buffer at 41.154545454545556
# Package TLMD183249897970 sorted to TLMD Buffer using tm_nonpit_buffer at 41.17076167076172
# Package TLMD183249917984 sorted to TLMD Buffer using tm_nonpit_buffer at 41.17076167076172
# Using tm_nonpit_buffer for sorting package TLMD61949711026 at 41.17076167076172
# Using tm_nonpit_buffer for sorting package TLMD183249733879 at 41.17076167076172
# Package 7.40E+11, FDEG inducted at 41.204545454545595
# Package 7.40E+11 split to National Sort at 41.204545454545595
# Package 7.40E+11, FDEG inducted at 41.22954545454556
# Package TLMD183249896435, TLMD inducted at 41.22954545454556
# Package TLMD183249892626, TLMD inducted at 41.22954545454556
# Package 7.40E+11 split to National Sort at 41.22954545454556
# Package TLMD183249896435 split to TLMD Buffer at 41.22954545454556
# Package TLMD183249892626 split to TLMD Buffer at 41.22954545454556
# Package TLMD183249918447 sorted to TLMD Buffer using tm_nonpit_buffer at 41.24576167076172
# Using tm_nonpit_buffer for sorting package TLMD183249904747 at 41.24576167076172
# Package TLMD183249897498, TLMD inducted at 41.2795454545456
# Package TLMD183249897498 split to TLMD Buffer at 41.2795454545456
# Package TLMD183249916458 sorted to TLMD Buffer using tm_nonpit_buffer at 41.29576167076176
# Using tm_nonpit_buffer for sorting package TLMD183249893161 at 41.29576167076176
# Package 7.40E+11, FDEG inducted at 41.30454545454556
# Package 9.26129E+21, USPS inducted at 41.30454545454556
# Package TLMD183249908403, TLMD inducted at 41.30454545454556
# Package 7.40E+11 split to National Sort at 41.30454545454556
# Package 9.26129E+21 split to National Sort at 41.30454545454556
# Package TLMD183249908403 split to TLMD Buffer at 41.30454545454556
# Package TLMD183249900938 sorted to TLMD Buffer using tm_nonpit_buffer at 41.320761670761726
# Using tm_nonpit_buffer for sorting package TLMD183249899987 at 41.320761670761726
# Package TLMD183249900803, TLMD inducted at 41.3545454545456
# Package TLMD183249900803 split to TLMD Buffer at 41.3545454545456
# Package TLMD183249898620, TLMD inducted at 41.379545454545564
# Package TLMD183249912818, TLMD inducted at 41.379545454545564
# Package TLMD183249906236, TLMD inducted at 41.379545454545564
# Package TLMD183249898620 split to TLMD Buffer at 41.379545454545564
# Package TLMD183249912818 split to TLMD Buffer at 41.379545454545564
# Package TLMD183249906236 split to TLMD Buffer at 41.379545454545564
# Package TLMD183249906601, TLMD inducted at 41.429545454545604
# Package TLMD183249906601 split to TLMD Buffer at 41.429545454545604
# Package 7.40E+11, FDEG inducted at 41.45454545454557
# Package 7.40E+11, FDEG inducted at 41.45454545454557
# Package TLMD61949770632, TLMD inducted at 41.45454545454557
# Package 7.40E+11 split to National Sort at 41.45454545454557
# Package 7.40E+11 split to National Sort at 41.45454545454557
# Package TLMD61949770632 split to TLMD Buffer at 41.45454545454557
# Package TLMD183249914487 sorted to TLMD Buffer using tm_nonpit_buffer at 41.50116707616712
# Package TLMD61949693574 sorted to TLMD Buffer using tm_nonpit_buffer at 41.50116707616712
# Package TLMD183249898362 sorted to TLMD Buffer using tm_nonpit_buffer at 41.50116707616712
# Using tm_nonpit_buffer for sorting package TLMD183249893812 at 41.50116707616712
# Using tm_nonpit_buffer for sorting package TLMD183249907182 at 41.50116707616712
# Using tm_nonpit_buffer for sorting package TLMD61949678260 at 41.50116707616712
# Package 9.26129E+21, USPS inducted at 41.50454545454561
# Package 9.26129E+21 split to National Sort at 41.50454545454561
# Package TLMD183249918661, TLMD inducted at 41.52954545454557
# Package TLMD183249897792, TLMD inducted at 41.52954545454557
# Package 7.40E+11, FDEG inducted at 41.52954545454557
# Package TLMD183249918661 split to TLMD Buffer at 41.52954545454557
# Package TLMD183249897792 split to TLMD Buffer at 41.52954545454557
# Package 7.40E+11 split to National Sort at 41.52954545454557
# Package TLMD61949711026 sorted to TLMD Buffer using tm_nonpit_buffer at 41.576167076167124
# Package TLMD183249733879 sorted to TLMD Buffer using tm_nonpit_buffer at 41.576167076167124
# Using tm_nonpit_buffer for sorting package TLMD183249903266 at 41.576167076167124
# Using tm_nonpit_buffer for sorting package TLMD183249765684 at 41.576167076167124
# Package 9.26129E+21, USPS inducted at 41.57954545454561
# Package 9.26129E+21 split to National Sort at 41.57954545454561
# Package TLMD183249902730, TLMD inducted at 41.60454545454557
# Package TLMD183249914656, TLMD inducted at 41.60454545454557
# Package TLMD183249901535, TLMD inducted at 41.60454545454557
# Package TLMD183249902730 split to TLMD Buffer at 41.60454545454557
# Package TLMD183249914656 split to TLMD Buffer at 41.60454545454557
# Package TLMD183249901535 split to TLMD Buffer at 41.60454545454557
# Package TLMD183249904747 sorted to TLMD Buffer using tm_nonpit_buffer at 41.65116707616713
# Using tm_nonpit_buffer for sorting package TLMD183249906192 at 41.65116707616713
# Package TLMD183249896097, TLMD inducted at 41.65454545454561
# Package TLMD183249896097 split to TLMD Buffer at 41.65454545454561
# Package 1Z300FX3YW43259972, UPSN inducted at 41.679545454545575
# Package TLMD61949678251, TLMD inducted at 41.679545454545575
# Package TLMD183249902936, TLMD inducted at 41.679545454545575
# Package 1Z300FX3YW43259972 split to National Sort at 41.679545454545575
# Package TLMD61949678251 split to TLMD Buffer at 41.679545454545575
# Package TLMD183249902936 split to TLMD Buffer at 41.679545454545575
# ...
# Using tm_nonpit_buffer for sorting package TLMD940749801018 at 540.1052211302234
# Package TLMD940749751911 sorted to TLMD Buffer using tm_nonpit_buffer at 540.1802211302235
# Package TLMD940749705060 sorted to TLMD Buffer using tm_nonpit_buffer at 540.1802211302235
# Package TLMD940749819036 sorted to TLMD Buffer using tm_nonpit_buffer at 540.1802211302235
# Using tm_nonpit_buffer for sorting package TLMD940749895954 at 540.1802211302235
# Using tm_nonpit_buffer for sorting package TLMD940749827938 at 540.1802211302235
# Using tm_nonpit_buffer for sorting package TLM940775965312 at 540.1802211302235
# Package TLMD940749814068 sorted to TLMD Buffer using tm_nonpit_buffer at 540.2552211302234
# Package TLM940775966930 sorted to TLMD Buffer using tm_nonpit_buffer at 540.2552211302234
# Using tm_nonpit_buffer for sorting package TLM940775975220 at 540.2552211302234
# Using tm_nonpit_buffer for sorting package TLMD940749894455 at 540.2552211302234
# Package TLMD940749942189 sorted to TLMD Buffer using tm_nonpit_buffer at 540.5106265356288
# Package TLM940775967631 sorted to TLMD Buffer using tm_nonpit_buffer at 540.5106265356288
# Package TLMD940749801018 sorted to TLMD Buffer using tm_nonpit_buffer at 540.5106265356288
# Using tm_nonpit_buffer for sorting package TLMD940749791502 at 540.5106265356288
# Using tm_nonpit_buffer for sorting package TLM940775974529 at 540.5106265356288
# Using tm_nonpit_buffer for sorting package TLMD940749823825 at 540.5106265356288
# Package TLMD940749895954 sorted to TLMD Buffer using tm_nonpit_buffer at 540.5856265356289
# Package TLMD940749827938 sorted to TLMD Buffer using tm_nonpit_buffer at 540.5856265356289
# Package TLM940775965312 sorted to TLMD Buffer using tm_nonpit_buffer at 540.5856265356289
# Using tm_nonpit_buffer for sorting package TLMD940749815718 at 540.5856265356289
# Using tm_nonpit_buffer for sorting package TLMD940749814844 at 540.5856265356289
# Using tm_nonpit_buffer for sorting package TLM940775976145 at 540.5856265356289
# Package TLM940775975220 sorted to TLMD Buffer using tm_nonpit_buffer at 540.6606265356288
# Package TLMD940749894455 sorted to TLMD Buffer using tm_nonpit_buffer at 540.6606265356288
# Using tm_nonpit_buffer for sorting package TLMD940749878240 at 540.6606265356288
# Using tm_nonpit_buffer for sorting package TLMD940749887589 at 540.6606265356288
# Package TLMD940749791502 sorted to TLMD Buffer using tm_nonpit_buffer at 540.9160319410342
# Package TLM940775974529 sorted to TLMD Buffer using tm_nonpit_buffer at 540.9160319410342
# Package TLMD940749823825 sorted to TLMD Buffer using tm_nonpit_buffer at 540.9160319410342
# Using tm_nonpit_buffer for sorting package TLMD940749881343 at 540.9160319410342
# Using tm_nonpit_buffer for sorting package TLMD940749894606 at 540.9160319410342
# Using tm_nonpit_buffer for sorting package TLMD940749880899 at 540.9160319410342
# Package TLMD940749815718 sorted to TLMD Buffer using tm_nonpit_buffer at 540.9910319410343
# Package TLMD940749814844 sorted to TLMD Buffer using tm_nonpit_buffer at 540.9910319410343
# Package TLM940775976145 sorted to TLMD Buffer using tm_nonpit_buffer at 540.9910319410343
# Using tm_nonpit_buffer for sorting package TLM940775971947 at 540.9910319410343
# Using tm_nonpit_buffer for sorting package TLMD940749818484 at 540.9910319410343
# Using tm_nonpit_buffer for sorting package TLMD940749803767 at 540.9910319410343
# Pallet 151.0 unloaded at 541.0
# Package TLMD940749878240 sorted to TLMD Buffer using tm_nonpit_buffer at 541.0660319410342
# Package TLMD940749887589 sorted to TLMD Buffer using tm_nonpit_buffer at 541.0660319410342
# Using tm_nonpit_buffer for sorting package TLMD940749817976 at 541.0660319410342
# Using tm_nonpit_buffer for sorting package TLMD940749841190 at 541.0660319410342
# Package TLMD940749881343 sorted to TLMD Buffer using tm_nonpit_buffer at 541.3214373464397
# Package TLMD940749894606 sorted to TLMD Buffer using tm_nonpit_buffer at 541.3214373464397
# Package TLMD940749880899 sorted to TLMD Buffer using tm_nonpit_buffer at 541.3214373464397
# Using tm_nonpit_buffer for sorting package TLMD940749781700 at 541.3214373464397
# Using tm_nonpit_buffer for sorting package TLMD940749752581 at 541.3214373464397
# Using tm_nonpit_buffer for sorting package TLMD940749907628 at 541.3214373464397
# Package TLM940775971947 sorted to TLMD Buffer using tm_nonpit_buffer at 541.3964373464397
# Package TLMD940749818484 sorted to TLMD Buffer using tm_nonpit_buffer at 541.3964373464397
# Package TLMD940749803767 sorted to TLMD Buffer using tm_nonpit_buffer at 541.3964373464397
# Using tm_nonpit_buffer for sorting package TLMD940749895025 at 541.3964373464397
# Using tm_nonpit_buffer for sorting package TLMD940749817172 at 541.3964373464397
# Using tm_nonpit_buffer for sorting package TLMD940749834626 at 541.3964373464397
# Package TLMD940749817976 sorted to TLMD Buffer using tm_nonpit_buffer at 541.4714373464396
# Package TLMD940749841190 sorted to TLMD Buffer using tm_nonpit_buffer at 541.4714373464396
# Using tm_nonpit_buffer for sorting package TLM940775971509 at 541.4714373464396
# Using tm_nonpit_buffer for sorting package TLMD940749803114 at 541.4714373464396
# Package TLMD940749781700 sorted to TLMD Buffer using tm_nonpit_buffer at 541.7268427518451
# Package TLMD940749752581 sorted to TLMD Buffer using tm_nonpit_buffer at 541.7268427518451
# Package TLMD940749907628 sorted to TLMD Buffer using tm_nonpit_buffer at 541.7268427518451
# Using tm_nonpit_buffer for sorting package TLMD940749834224 at 541.7268427518451
# Using tm_nonpit_buffer for sorting package TLMD940749813087 at 541.7268427518451
# Using tm_nonpit_buffer for sorting package TLMD940749822451 at 541.7268427518451
# Package TLMD940749895025 sorted to TLMD Buffer using tm_nonpit_buffer at 541.8018427518451
# Package TLMD940749817172 sorted to TLMD Buffer using tm_nonpit_buffer at 541.8018427518451
# Package TLMD940749834626 sorted to TLMD Buffer using tm_nonpit_buffer at 541.8018427518451
# Using tm_nonpit_buffer for sorting package TLMD940749873781 at 541.8018427518451
# Using tm_nonpit_buffer for sorting package TLMD940749822344 at 541.8018427518451
# Using tm_nonpit_buffer for sorting package TLMD940749900974 at 541.8018427518451
# Package TLM940775971509 sorted to TLMD Buffer using tm_nonpit_buffer at 541.8768427518451
# Package TLMD940749803114 sorted to TLMD Buffer using tm_nonpit_buffer at 541.8768427518451
# Using tm_nonpit_buffer for sorting package TLMD940749828517 at 541.8768427518451
# Using tm_nonpit_buffer for sorting package TLM940775976369 at 541.8768427518451
# Package TLMD940749834224 sorted to TLMD Buffer using tm_nonpit_buffer at 542.1322481572505
# Package TLMD940749813087 sorted to TLMD Buffer using tm_nonpit_buffer at 542.1322481572505
# Package TLMD940749822451 sorted to TLMD Buffer using tm_nonpit_buffer at 542.1322481572505
# Using tm_nonpit_buffer for sorting package TLM940775974967 at 542.1322481572505
# Using tm_nonpit_buffer for sorting package TLMD940749819867 at 542.1322481572505
# Using tm_nonpit_buffer for sorting package TLM940775968811 at 542.1322481572505
# Package TLMD940749873781 sorted to TLMD Buffer using tm_nonpit_buffer at 542.2072481572505
# Package TLMD940749822344 sorted to TLMD Buffer using tm_nonpit_buffer at 542.2072481572505
# Package TLMD940749900974 sorted to TLMD Buffer using tm_nonpit_buffer at 542.2072481572505
# Using tm_nonpit_buffer for sorting package TLMD940749799559 at 542.2072481572505
# Using tm_nonpit_buffer for sorting package TLMD940749945846 at 542.2072481572505
# Using tm_nonpit_buffer for sorting package TLM940775978357 at 542.2072481572505
# Package TLMD940749828517 sorted to TLMD Buffer using tm_nonpit_buffer at 542.2822481572505
# Package TLM940775976369 sorted to TLMD Buffer using tm_nonpit_buffer at 542.2822481572505
# Using tm_nonpit_buffer for sorting package TLMD940749842242 at 542.2822481572505
# Using tm_nonpit_buffer for sorting package TLMD940749876706 at 542.2822481572505
# Package TLM940775974967 sorted to TLMD Buffer using tm_nonpit_buffer at 542.5376535626559
# Package TLMD940749819867 sorted to TLMD Buffer using tm_nonpit_buffer at 542.5376535626559
# Package TLM940775968811 sorted to TLMD Buffer using tm_nonpit_buffer at 542.5376535626559
# Using tm_nonpit_buffer for sorting package TLM940775965643 at 542.5376535626559
# Using tm_nonpit_buffer for sorting package TLMD940749766530 at 542.5376535626559
# Using tm_nonpit_buffer for sorting package TLM940775971468 at 542.5376535626559
# Package TLMD940749799559 sorted to TLMD Buffer using tm_nonpit_buffer at 542.612653562656
# Package TLMD940749945846 sorted to TLMD Buffer using tm_nonpit_buffer at 542.612653562656
# Package TLM940775978357 sorted to TLMD Buffer using tm_nonpit_buffer at 542.612653562656
# Using tm_nonpit_buffer for sorting package TLMD940749883985 at 542.612653562656
# Using tm_nonpit_buffer for sorting package TLMD940749837945 at 542.612653562656
# Using tm_nonpit_buffer for sorting package TLMD940749813103 at 542.612653562656
# Package TLMD940749842242 sorted to TLMD Buffer using tm_nonpit_buffer at 542.6876535626559
# Package TLMD940749876706 sorted to TLMD Buffer using tm_nonpit_buffer at 542.6876535626559
# Using tm_nonpit_buffer for sorting package TLM940775970436 at 542.6876535626559
# Using tm_nonpit_buffer for sorting package TLMD940749820097 at 542.6876535626559
# Pallet 150.0 staged for induction at 542.7272727272727
# Package TLMD940749762785, TLMD inducted at 542.8022727272728
# Package TLMD940749958181, TLMD inducted at 542.8022727272728
# Package TLMD940749762785 split to TLMD Buffer at 542.8022727272728
# Pallet 150.0 removed from queue_induct_staging_pallets at 542.8022727272728
# Package TLMD940749958181 split to TLMD Buffer at 542.8022727272728
# Package TLM940775965643 sorted to TLMD Buffer using tm_nonpit_buffer at 542.9430589680613
# Package TLMD940749766530 sorted to TLMD Buffer using tm_nonpit_buffer at 542.9430589680613
# Package TLM940775971468 sorted to TLMD Buffer using tm_nonpit_buffer at 542.9430589680613
# Using tm_nonpit_buffer for sorting package TLM940775965536 at 542.9430589680613
# Using tm_nonpit_buffer for sorting package TLMD940749830595 at 542.9430589680613
# Using tm_nonpit_buffer for sorting package TLMD940749826779 at 542.9430589680613
# Package TLMD940749883985 sorted to TLMD Buffer using tm_nonpit_buffer at 543.0180589680614
# Package TLMD940749837945 sorted to TLMD Buffer using tm_nonpit_buffer at 543.0180589680614
# Package TLMD940749813103 sorted to TLMD Buffer using tm_nonpit_buffer at 543.0180589680614
# Using tm_nonpit_buffer for sorting package TLMD940749774469 at 543.0180589680614
# Using tm_nonpit_buffer for sorting package TLMD940749986025 at 543.0180589680614
# Using tm_nonpit_buffer for sorting package TLMD940749703286 at 543.0180589680614
# Package TLM940775970436 sorted to TLMD Buffer using tm_nonpit_buffer at 543.0930589680613
# Package TLMD940749820097 sorted to TLMD Buffer using tm_nonpit_buffer at 543.0930589680613
# Using tm_nonpit_buffer for sorting package TLMD940749802115 at 543.0930589680613
# Using tm_nonpit_buffer for sorting package TLMD940749973897 at 543.0930589680613
# Package TLM940775965536 sorted to TLMD Buffer using tm_nonpit_buffer at 543.3484643734668
# Package TLMD940749830595 sorted to TLMD Buffer using tm_nonpit_buffer at 543.3484643734668
# Package TLMD940749826779 sorted to TLMD Buffer using tm_nonpit_buffer at 543.3484643734668
# Using tm_nonpit_buffer for sorting package TLM940775972862 at 543.3484643734668
# Using tm_nonpit_buffer for sorting package TLMD940749945953 at 543.3484643734668
# Using tm_nonpit_buffer for sorting package TLM940775966568 at 543.3484643734668
# Package TLMD940749774469 sorted to TLMD Buffer using tm_nonpit_buffer at 543.4234643734668
# Package TLMD940749986025 sorted to TLMD Buffer using tm_nonpit_buffer at 543.4234643734668
# Package TLMD940749703286 sorted to TLMD Buffer using tm_nonpit_buffer at 543.4234643734668
# Using tm_nonpit_buffer for sorting package TLMD940749732923 at 543.4234643734668
# Using tm_nonpit_buffer for sorting package TLMD940749949799 at 543.4234643734668
# Using tm_nonpit_buffer for sorting package TLMD940749704418 at 543.4234643734668
# Package TLMD940749802115 sorted to TLMD Buffer using tm_nonpit_buffer at 543.4984643734667
# Package TLMD940749973897 sorted to TLMD Buffer using tm_nonpit_buffer at 543.4984643734667
# Using tm_nonpit_buffer for sorting package TLMD940749762785 at 543.4984643734667
# Using tm_nonpit_buffer for sorting package TLMD940749958181 at 543.4984643734667
# Pallet 151.0 staged for induction at 543.7272727272727
# Package TLM940775972862 sorted to TLMD Buffer using tm_nonpit_buffer at 543.7538697788722
# Package TLMD940749945953 sorted to TLMD Buffer using tm_nonpit_buffer at 543.7538697788722
# Package TLM940775966568 sorted to TLMD Buffer using tm_nonpit_buffer at 543.7538697788722
# Package TLMD940749767833, TLMD inducted at 543.8022727272728
# Package TLMD940749883207, TLMD inducted at 543.8022727272728
# Package TLMD940749761875, TLMD inducted at 543.8022727272728
# Package TLMD940749854560, TLMD inducted at 543.8022727272728
# Package TLMD940749767833 split to TLMD Buffer at 543.8022727272728
# Using tm_nonpit_buffer for sorting package TLMD940749767833 at 543.8022727272728
# Package TLMD940749883207 split to TLMD Buffer at 543.8022727272728
# Using tm_nonpit_buffer for sorting package TLMD940749883207 at 543.8022727272728
# Package TLMD940749761875 split to TLMD Buffer at 543.8022727272728
# Using tm_nonpit_buffer for sorting package TLMD940749761875 at 543.8022727272728
# Package TLMD940749854560 split to TLMD Buffer at 543.8022727272728
# Package TLMD940749732923 sorted to TLMD Buffer using tm_nonpit_buffer at 543.8288697788722
# Package TLMD940749949799 sorted to TLMD Buffer using tm_nonpit_buffer at 543.8288697788722
# Package TLMD940749704418 sorted to TLMD Buffer using tm_nonpit_buffer at 543.8288697788722
# Using tm_nonpit_buffer for sorting package TLMD940749854560 at 543.8288697788722
# Package TLMD940749789613, TLMD inducted at 543.8772727272728
# Pallet 151.0 removed from queue_induct_staging_pallets at 543.8772727272728
# Package TLMD940749789613 split to TLMD Buffer at 543.8772727272728
# Using tm_nonpit_buffer for sorting package TLMD940749789613 at 543.8772727272728
# Package TLMD940749762785 sorted to TLMD Buffer using tm_nonpit_buffer at 543.9038697788721
# Package TLMD940749958181 sorted to TLMD Buffer using tm_nonpit_buffer at 543.9038697788721
# Pallet 152.0 unloaded at 544.0
# Package TLMD940749767833 sorted to TLMD Buffer using tm_nonpit_buffer at 544.2076781326782
# Package TLMD940749883207 sorted to TLMD Buffer using tm_nonpit_buffer at 544.2076781326782
# Package TLMD940749761875 sorted to TLMD Buffer using tm_nonpit_buffer at 544.2076781326782
# Package TLMD940749854560 sorted to TLMD Buffer using tm_nonpit_buffer at 544.2342751842776
# Package TLMD940749789613 sorted to TLMD Buffer using tm_nonpit_buffer at 544.2826781326783
# Pallet 152.0 staged for induction at 546.7272727272727
# Package TLMD940749684137, TLMD inducted at 546.8022727272728
# Pallet 152.0 removed from queue_induct_staging_pallets at 546.8022727272728
# Package TLMD940749684137 split to TLMD Buffer at 546.8022727272728
# Using tm_nonpit_buffer for sorting package TLMD940749684137 at 546.8022727272728
# Package TLMD940749684137 sorted to TLMD Buffer using tm_nonpit_buffer at 547.2076781326782
# End Induct Process
# C:\Users\fenst\AppData\Local\Temp\ipykernel_13284\1634360541.py:184: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 57
#      54 print("End Induct Process")
#      56 plot_metrics(sortation_center.metrics)
# ---> 57 print(len(G.TLMD_STAGED_PACKAGES))
#      58 # Setup TLMD Sort simulation
#      59 env, sortation_center = setup_simulation_2(G.TLMD_STAGED_PACKAGES, night_tm_TLMD_induct, night_tm_TLMD_picker, night_tm_TLMD_sort, unavailable_periods)
#
# TypeError: object of type 'NoneType' has no len()

# %%
print(f'Induct Line Run as Batch Process:')
print("...................................")
print(f'Induct process completed at {G.TLMD_INDUCT_TIME}')
print(f'UPSN Packages staged for handoff at {G.UPSN_SORT_TIME}')
print(f'USPS Packages staged for handoff at {G.USPS_SORT_TIME}')
print(f'FDEG Packages staged for handoff at {G.FDEG_SORT_TIME}')
print(f'FDE Packages staged for handoff at {G.FDE_SORT_TIME}')
print("...................................")
print(f'Begin TLMD Sort Process:')
print("...................................")
print(f'Partition 1 sort process completed at {G.TLMD_PARTITION_1_SORT_TIME}')
print(f'Partition 2 sort process completed at {G.TLMD_PARTITION_2_SORT_TIME}')
print(f'Partition 3 sort process completed at {G.TLMD_PARTITION_3_SORT_TIME}')
print(f'Partition 1 cart staging completed at {G.TLMD_PARTITION_1_CART_STAGE_TIME}')
print(f'Partition 2 cart staging completed at {G.TLMD_PARTITION_2_CART_STAGE_TIME}')
print(f'Partition 3 cart staging completed at {G.TLMD_PARTITION_3_CART_STAGE_TIME}')
